# %%
from tpot import TPOTClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import numpy as np

iris = load_iris() # cargar base

# dividir base en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(iris.data.astype(np.float64),
    iris.target.astype(np.float64), train_size=0.75, test_size=0.25, random_state=42) 

# crear clasificador
tpot = TPOTClassifier(generations=5, population_size=50, verbosity=2, random_state=42)

# entrenar clasificador con datos de entrenamiento
tpot.fit(X_train, y_train)

# metricas de evaluación: evaluar pipeline
print(tpot.score(X_test, y_test))
tpot.export('tpot_iris_pipeline.py')

# obtener base preprocesada
preprocess_data=tpot.predict(X_train)
# Out:
# Warning: sklearn.kernel_approximation.Nystroem is not available and will not be used by TPOT.
# Warning: sklearn.kernel_approximation.RBFSampler is not available and will not be used by TPOT.
# Optimization Progress:   0%|          | 0/300 [00:00<?, ?pipeline/s]
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: DecisionTreeClassifier(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False), criterion=entropy, max_depth=4, min_samples_leaf=20, min_samples_split=10)
# 0.9736842105263158
# /home/diego-pc/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:780: FutureWarning: sklearn.metrics.SCORERS is deprecated and will be removed in v1.3. Please use sklearn.metrics.get_scorer_names to get a list of available scorers and sklearn.metrics.get_metric to get scorer.
#   warnings.warn(

# %%
preprocess_data
# Out:
# array([0., 0., 2., 1., 1., 0., 0., 1., 2., 2., 1., 2., 1., 2., 1., 0., 2.,
#        1., 0., 0., 0., 1., 2., 0., 0., 0., 1., 0., 1., 2., 0., 1., 2., 0.,
#        2., 2., 1., 1., 2., 1., 0., 1., 2., 0., 0., 1., 1., 0., 2., 0., 0.,
#        1., 1., 2., 2., 2., 2., 1., 0., 0., 2., 2., 0., 0., 0., 2., 2., 0.,
#        2., 2., 0., 1., 1., 2., 1., 2., 0., 2., 1., 2., 1., 1., 1., 0., 1.,
#        1., 0., 1., 2., 2., 0., 1., 2., 2., 0., 2., 0., 1., 2., 2., 1., 2.,
#        1., 1., 2., 2., 0., 1., 2., 0., 1., 2.])

# %%
# atributos de pipeline TPOTClassifier
tpot.fitted_pipeline_ # mejor pipeline
tpot.pareto_front_fitted_pipelines_ # dic. con todos los pipelines
tpot.evaluated_individuals_ # pipelines evaluados
# Out:
# {'GaussianNB(input_matrix)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9280632411067193},
#  'RandomForestClassifier(MinMaxScaler(input_matrix), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9458498023715414},
#  'XGBClassifier(MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False), XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=13, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.3482213438735178},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.8747035573122529},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=3, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9549407114624506},
#  'LinearSVC(SelectFwe(input_matrix, SelectFwe__alpha=0.036000000000000004), LinearSVC__C=0.0001, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.3391304347826087},
#  'MultinomialNB(Nystroem(input_matrix, Nystroem__gamma=0.30000000000000004, Nystroem__kernel=cosine, Nystroem__n_components=3), MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6897233201581028},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.901185770750988},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.8, ExtraTreesClassifier__min_samples_leaf=19, ExtraTreesClassifier__min_samples_split=5, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.8920948616600791},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=10, XGBClassifier__min_child_weight=17, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=1.0, XGBClassifier__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.8395256916996047},
#  'BernoulliNB(SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.5, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.1), BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=False)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6608695652173913},
#  'XGBClassifier(XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=8, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=1.0, XGBClassifier__verbosity=0), XGBClassifier__learning_rate=1.0, XGBClassifier__max_depth=2, XGBClassifier__min_child_weight=10, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.9500000000000001, XGBClassifier__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9458498023715414},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9549407114624506},
#  'GaussianNB(RobustScaler(input_matrix))': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9280632411067193},
#  'MLPClassifier(input_matrix, MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9727272727272727},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=10, XGBClassifier__min_child_weight=20, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.8, XGBClassifier__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3300395256916996},
#  'XGBClassifier(FastICA(input_matrix, FastICA__tol=0.05), XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=17, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.6500000000000001, XGBClassifier__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.3482213438735178},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=5, XGBClassifier__min_child_weight=14, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.15000000000000002, XGBClassifier__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3126482213438735},
#  'MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=27), MultinomialNB__alpha=1.0, MultinomialNB__fit_prior=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.3482213438735178},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=20, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9371541501976285},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9201581027667984},
#  'MLPClassifier(FeatureAgglomeration(input_matrix, FeatureAgglomeration__affinity=manhattan, FeatureAgglomeration__linkage=average), MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=0.01)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.8750988142292491},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6972332015810276},
#  'DecisionTreeClassifier(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=17, ExtraTreesClassifier__min_samples_split=16, ExtraTreesClassifier__n_estimators=100), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=7)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9280632411067193},
#  'KNeighborsClassifier(Binarizer(input_matrix, Binarizer__threshold=0.9), KNeighborsClassifier__n_neighbors=34, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6608695652173913},
#  'BernoulliNB(MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6608695652173913},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3482213438735178},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9553359683794467},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.1, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.0, SGDClassifier__learning_rate=constant, SGDClassifier__loss=hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.7577075098814229},
#  'RandomForestClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.7000000000000001, RandomForestClassifier__min_samples_leaf=11, RandomForestClassifier__min_samples_split=10, RandomForestClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9545454545454547},
#  'MLPClassifier(input_matrix, MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=1.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3853754940711462},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.6000000000000001, ExtraTreesClassifier__min_samples_leaf=16, ExtraTreesClassifier__min_samples_split=11, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9189723320158103},
#  'KNeighborsClassifier(SelectFromModel(input_matrix, SelectFromModel__ExtraTreesClassifier__criterion=entropy, SelectFromModel__ExtraTreesClassifier__max_features=0.7000000000000001, SelectFromModel__ExtraTreesClassifier__n_estimators=100, SelectFromModel__threshold=0.4), KNeighborsClassifier__n_neighbors=52, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9288537549407115},
#  'RandomForestClassifier(MLPClassifier(input_matrix, MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.01), RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=1.0, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=20, RandomForestClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9553359683794467},
#  'DecisionTreeClassifier(KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=14, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=1, DecisionTreeClassifier__min_samples_split=11)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9458498023715414},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3482213438735178},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=72, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3482213438735178},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.001, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=1.0, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6533596837944664},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6517786561264821},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.45, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=15, RandomForestClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9189723320158103},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=1.0, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9276679841897233},
#  'LogisticRegression(input_matrix, LogisticRegression__C=25.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9458498023715414},
#  'LinearSVC(RobustScaler(input_matrix), LinearSVC__C=0.001, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.7675889328063242},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9197628458498024},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.45, ExtraTreesClassifier__min_samples_leaf=20, ExtraTreesClassifier__min_samples_split=13, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.8470355731225296},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=1.0, MultinomialNB__fit_prior=False)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9549407114624506},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.25, ExtraTreesClassifier__min_samples_leaf=17, ExtraTreesClassifier__min_samples_split=16, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.8837944664031621},
#  'RandomForestClassifier(FastICA(input_matrix, FastICA__tol=0.8), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=16, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': 0.874308300395257},
#  'RandomForestClassifier(FastICA(input_matrix, FastICA__tol=0.35000000000000003), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=1.0, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=1.0, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.8920948616600791},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3482213438735178},
#  'BernoulliNB(SGDClassifier(input_matrix, SGDClassifier__alpha=0.001, SGDClassifier__eta0=0.1, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.0, SGDClassifier__learning_rate=constant, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=50.0), BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6517786561264821},
#  'MultinomialNB(LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=1e-05), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9193675889328062},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=1, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.8500000000000001, XGBClassifier__verbosity=0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9545454545454547},
#  'DecisionTreeClassifier(PolynomialFeatures(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=17, ExtraTreesClassifier__min_samples_split=16, ExtraTreesClassifier__n_estimators=100), PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=7)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=17, ExtraTreesClassifier__min_samples_split=16, ExtraTreesClassifier__n_estimators=100), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=7)',),
#   'operator_count': 3,
#   'internal_cv_score': 0.9636363636363636},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9193675889328062},
#  'XGBClassifier(FastICA(input_matrix, FastICA__tol=0.05), XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=2, XGBClassifier__min_child_weight=17, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.6500000000000001, XGBClassifier__verbosity=0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('XGBClassifier(FastICA(input_matrix, FastICA__tol=0.05), XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=17, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.6500000000000001, XGBClassifier__verbosity=0)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.3482213438735178},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=True)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3482213438735178},
#  'KNeighborsClassifier(GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.01, GradientBoostingClassifier__max_depth=5, GradientBoostingClassifier__max_features=0.15000000000000002, GradientBoostingClassifier__min_samples_leaf=8, GradientBoostingClassifier__min_samples_split=5, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.45), KNeighborsClassifier__n_neighbors=72, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=72, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.3482213438735178},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=34, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('KNeighborsClassifier(Binarizer(input_matrix, Binarizer__threshold=0.9), KNeighborsClassifier__n_neighbors=34, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)',
#    'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=3, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)'),
#   'operator_count': 1,
#   'internal_cv_score': 0.901185770750988},
#  'SGDClassifier(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.001), SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6972332015810276},
#  'MultinomialNB(SelectPercentile(SGDClassifier(input_matrix, SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.1, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=1.0, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0), SelectPercentile__percentile=27), MultinomialNB__alpha=1.0, MultinomialNB__fit_prior=True)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=27), MultinomialNB__alpha=1.0, MultinomialNB__fit_prior=True)',),
#   'operator_count': 3,
#   'internal_cv_score': 0.8130434782608695},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)',
#    'XGBClassifier(MultinomialNB(input_matrix, MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=False), XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=13, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)'),
#   'operator_count': 1,
#   'internal_cv_score': 0.9106719367588931},
#  'DecisionTreeClassifier(KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=14, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=11, DecisionTreeClassifier__min_samples_split=11)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=14, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=1, DecisionTreeClassifier__min_samples_split=11)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9458498023715414},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.0, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.6245059288537549},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=3, ExtraTreesClassifier__min_samples_split=8, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GaussianNB(input_matrix)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9280632411067193},
#  'BernoulliNB(XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=9, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.9000000000000001, XGBClassifier__verbosity=0), BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=False)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.6521739130434783},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.45, ExtraTreesClassifier__min_samples_leaf=20, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.45, ExtraTreesClassifier__min_samples_leaf=20, ExtraTreesClassifier__min_samples_split=13, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.8470355731225296},
#  'DecisionTreeClassifier(KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=14, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=1, DecisionTreeClassifier__min_samples_split=11)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=14, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=1, DecisionTreeClassifier__min_samples_split=11)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9458498023715414},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.45, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=15, RandomForestClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.45, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=15, RandomForestClassifier__n_estimators=100)',
#    'RandomForestClassifier(FastICA(input_matrix, FastICA__tol=0.8), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.5, RandomForestClassifier__min_samples_leaf=16, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100)'),
#   'operator_count': 1,
#   'internal_cv_score': 0.9367588932806324},
#  'XGBClassifier(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.7000000000000001, ExtraTreesClassifier__min_samples_leaf=20, ExtraTreesClassifier__min_samples_split=4, ExtraTreesClassifier__n_estimators=100), XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=5, XGBClassifier__min_child_weight=14, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.15000000000000002, XGBClassifier__verbosity=0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=5, XGBClassifier__min_child_weight=14, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.15000000000000002, XGBClassifier__verbosity=0)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.3126482213438735},
#  'LinearSVC(RobustScaler(input_matrix), LinearSVC__C=0.5, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVC(RobustScaler(input_matrix), LinearSVC__C=0.001, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.8569169960474309},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=20, ExtraTreesClassifier__min_samples_split=13, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.45, ExtraTreesClassifier__min_samples_leaf=20, ExtraTreesClassifier__min_samples_split=13, ExtraTreesClassifier__n_estimators=100)',
#    'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)'),
#   'operator_count': 1,
#   'internal_cv_score': 0.8470355731225296},
#  'ExtraTreesClassifier(MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=False), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9549407114624506},
#  'LinearSVC(RobustScaler(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.15, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10)), LinearSVC__C=0.001, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVC(RobustScaler(input_matrix), LinearSVC__C=0.001, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)',),
#   'operator_count': 3,
#   'internal_cv_score': 0.7675889328063242},
#  'ExtraTreesClassifier(Normalizer(input_matrix, Normalizer__norm=l1), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.8, ExtraTreesClassifier__min_samples_leaf=19, ExtraTreesClassifier__min_samples_split=5, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.8, ExtraTreesClassifier__min_samples_leaf=19, ExtraTreesClassifier__min_samples_split=5, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9102766798418973},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.55, XGBClassifier__verbosity=0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9280632411067193},
#  'XGBClassifier(RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.25, RandomForestClassifier__min_samples_leaf=16, RandomForestClassifier__min_samples_split=19, RandomForestClassifier__n_estimators=100), XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9367588932806324},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.5, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.5822134387351778},
#  'MLPClassifier(RBFSampler(input_matrix, RBFSampler__gamma=0.6000000000000001), MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('MLPClassifier(input_matrix, MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.001)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9371541501976285},
#  'XGBClassifier(BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False), XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.45, XGBClassifier__verbosity=0)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.8747035573122529},
#  'ExtraTreesClassifier(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.55, ExtraTreesClassifier__min_samples_leaf=3, ExtraTreesClassifier__min_samples_split=18, ExtraTreesClassifier__n_estimators=100), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9371541501976285},
#  'MultinomialNB(Nystroem(ZeroCount(input_matrix), Nystroem__gamma=0.30000000000000004, Nystroem__kernel=cosine, Nystroem__n_components=3), MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=True)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('MultinomialNB(Nystroem(input_matrix, Nystroem__gamma=0.30000000000000004, Nystroem__kernel=cosine, Nystroem__n_components=3), MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=True)',),
#   'operator_count': 3,
#   'internal_cv_score': 0.6446640316205534},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=5, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=3, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9284584980237154},
#  'BernoulliNB(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=entropy, RFE__ExtraTreesClassifier__max_features=0.6000000000000001, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.7000000000000001), BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.3482213438735178},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=17, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.6500000000000001, XGBClassifier__verbosity=0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('XGBClassifier(FastICA(input_matrix, FastICA__tol=0.05), XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=17, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.6500000000000001, XGBClassifier__verbosity=0)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3482213438735178},
#  'RandomForestClassifier(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.4, ExtraTreesClassifier__min_samples_leaf=7, ExtraTreesClassifier__min_samples_split=8, ExtraTreesClassifier__n_estimators=100), RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.45, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=15, RandomForestClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.45, RandomForestClassifier__min_samples_leaf=8, RandomForestClassifier__min_samples_split=15, RandomForestClassifier__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9284584980237154},
#  'LinearSVC(RobustScaler(input_matrix), LinearSVC__C=1.0, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVC(RobustScaler(input_matrix), LinearSVC__C=0.001, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.8747035573122529},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.8, ExtraTreesClassifier__min_samples_leaf=19, ExtraTreesClassifier__min_samples_split=16, ExtraTreesClassifier__n_estimators=100)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.8, ExtraTreesClassifier__min_samples_leaf=19, ExtraTreesClassifier__min_samples_split=5, ExtraTreesClassifier__n_estimators=100)',
#    'DecisionTreeClassifier(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=17, ExtraTreesClassifier__min_samples_split=16, ExtraTreesClassifier__n_estimators=100), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=7)'),
#   'operator_count': 1,
#   'internal_cv_score': 0.8920948616600791},
#  'MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=6), MultinomialNB__alpha=1.0, MultinomialNB__fit_prior=True)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('MultinomialNB(SelectPercentile(input_matrix, SelectPercentile__percentile=27), MultinomialNB__alpha=1.0, MultinomialNB__fit_prior=True)',),
# ...
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestClassifier(PolynomialFeatures(MultinomialNB(input_matrix, MultinomialNB__alpha=100.0, MultinomialNB__fit_prior=True), PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.7000000000000001, RandomForestClassifier__min_samples_leaf=11, RandomForestClassifier__min_samples_split=10, RandomForestClassifier__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9640316205533598},
#  'MLPClassifier(DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=1, DecisionTreeClassifier__min_samples_leaf=5, DecisionTreeClassifier__min_samples_split=15), MLPClassifier__alpha=0.01, MLPClassifier__learning_rate_init=0.001)': {'generation': 5,
#   'mutation_count': 4,
#   'crossover_count': 0,
#   'predecessor': ('MLPClassifier(DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=1, DecisionTreeClassifier__min_samples_leaf=5, DecisionTreeClassifier__min_samples_split=15), MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=0.001)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9727272727272727},
#  'DecisionTreeClassifier(RobustScaler(RFE(RobustScaler(PolynomialFeatures(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=17, ExtraTreesClassifier__min_samples_split=16, ExtraTreesClassifier__n_estimators=100), PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False)), RFE__ExtraTreesClassifier__criterion=entropy, RFE__ExtraTreesClassifier__max_features=0.55, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.7500000000000001)), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=7)': {'generation': 5,
#   'mutation_count': 4,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(RobustScaler(RobustScaler(PolynomialFeatures(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=17, ExtraTreesClassifier__min_samples_split=16, ExtraTreesClassifier__n_estimators=100), PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False))), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=7)',),
#   'operator_count': 6,
#   'internal_cv_score': 0.9636363636363636},
#  'ExtraTreesClassifier(GaussianNB(input_matrix), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=14, ExtraTreesClassifier__min_samples_split=11, ExtraTreesClassifier__n_estimators=100)': {'generation': 5,
#   'mutation_count': 4,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=14, ExtraTreesClassifier__min_samples_split=11, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9280632411067193},
#  'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.001, GradientBoostingClassifier__max_depth=9, GradientBoostingClassifier__max_features=0.9000000000000001, GradientBoostingClassifier__min_samples_leaf=20, GradientBoostingClassifier__min_samples_split=19, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=1.0)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=False)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9189723320158103},
#  'ExtraTreesClassifier(Normalizer(input_matrix, Normalizer__norm=l1), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=1, ExtraTreesClassifier__min_samples_split=20, ExtraTreesClassifier__n_estimators=100)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 1,
#   'predecessor': ('ExtraTreesClassifier(Normalizer(input_matrix, Normalizer__norm=l1), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=20, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9727272727272727},
#  'ExtraTreesClassifier(MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=False), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('ExtraTreesClassifier(MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=False), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.35000000000000003, ExtraTreesClassifier__min_samples_leaf=18, ExtraTreesClassifier__min_samples_split=9, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9549407114624506},
#  'ExtraTreesClassifier(MinMaxScaler(Normalizer(input_matrix, Normalizer__norm=l1)), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=20, ExtraTreesClassifier__n_estimators=100)': {'generation': 5,
#   'mutation_count': 4,
#   'crossover_count': 2,
#   'predecessor': ('ExtraTreesClassifier(Normalizer(input_matrix, Normalizer__norm=l1), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=20, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 3,
#   'internal_cv_score': 0.9557312252964426},
#  'MultinomialNB(MLPClassifier(input_matrix, MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=0.1), MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=False)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=False)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9553359683794467},
#  'MLPClassifier(MLPClassifier(input_matrix, MLPClassifier__alpha=0.001, MLPClassifier__learning_rate_init=0.1), MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.001)': {'generation': 5,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('MLPClassifier(input_matrix, MLPClassifier__alpha=0.0001, MLPClassifier__learning_rate_init=0.001)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9640316205533598},
#  'DecisionTreeClassifier(PolynomialFeatures(CombineDFs(input_matrix, input_matrix), PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=7)': {'generation': 5,
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=7)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9636363636363636},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=14, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'generation': 5,
#   'mutation_count': 3,
#   'crossover_count': 1,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=14, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=uniform)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9371541501976285},
#  'MultinomialNB(PolynomialFeatures(XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=11, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.6000000000000001, XGBClassifier__verbosity=0), PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=True)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('MultinomialNB(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), MultinomialNB__alpha=10.0, MultinomialNB__fit_prior=True)',),
#   'operator_count': 3,
#   'internal_cv_score': 0.88300395256917},
#  'ExtraTreesClassifier(Normalizer(RBFSampler(input_matrix, RBFSampler__gamma=0.8500000000000001), Normalizer__norm=l1), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=11, ExtraTreesClassifier__n_estimators=100)': {'generation': 5,
#   'mutation_count': 5,
#   'crossover_count': 2,
#   'predecessor': ('ExtraTreesClassifier(Normalizer(input_matrix, Normalizer__norm=l1), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.9000000000000001, ExtraTreesClassifier__min_samples_leaf=15, ExtraTreesClassifier__min_samples_split=11, ExtraTreesClassifier__n_estimators=100)',),
#   'operator_count': 3,
#   'internal_cv_score': 0.9640316205533598},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=False)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=False)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9549407114624506},
#  'MultinomialNB(RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.1, RandomForestClassifier__min_samples_leaf=9, RandomForestClassifier__min_samples_split=9, RandomForestClassifier__n_estimators=100), MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)': {'generation': 5,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9458498023715414},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=4, XGBClassifier__min_child_weight=1, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.8500000000000001, XGBClassifier__verbosity=0)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=1, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.8500000000000001, XGBClassifier__verbosity=0)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9545454545454547},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=5, XGBClassifier__min_child_weight=8, XGBClassifier__n_estimators=100, XGBClassifier__n_jobs=1, XGBClassifier__subsample=0.25, XGBClassifier__verbosity=0)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=21, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.3482213438735178},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=7)': {'generation': 5,
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=7)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9189723320158103},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=1.0, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=20, RandomForestClassifier__n_estimators=100)': {'generation': 5,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestClassifier(MLPClassifier(input_matrix, MLPClassifier__alpha=0.1, MLPClassifier__learning_rate_init=0.01), RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=1.0, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=20, RandomForestClassifier__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9189723320158103},
#  'ExtraTreesClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.15000000000000002, ExtraTreesClassifier__min_samples_leaf=3, ExtraTreesClassifier__min_samples_split=12, ExtraTreesClassifier__n_estimators=100)': {'generation': 5,
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=7, DecisionTreeClassifier__min_samples_leaf=18, DecisionTreeClassifier__min_samples_split=7)',),
#   'operator_count': 2,
#   'internal_cv_score': 0.9371541501976285},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=1, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)': {'generation': 5,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=3, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9375494071146246}}

# %%
# métodos (funciones) de pipeline TPOTClassifier
#tpot.fit(X_train, y_train)
tpot.predict(X_test) # predecir etiquetas
tpot.predict_proba(X_test) # predecir probabilidad de clase 
tpot.score(X_test, y_test) # metricas de evaluacion: evaluar accuracy
tpot.export('TPOTClassifier1')

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from tpot.export_utils import set_param_recursive

# NOTE: Make sure that the outcome column is labeled 'target' in the data file

tpot_data = pd.read_csv('PATH/TO/DATA/FILE', sep='COLUMN_SEPARATOR', dtype=np.float64) # cargar datos
features = tpot_data.drop('target', axis=1) # definir variables/predictores (X)
training_features, testing_features, training_target, testing_target = \
            train_test_split(features, tpot_data['target'], random_state=42) # dividir en datos de entrenamiento y prueba 

# Average CV score on the training set was: 0.9826086956521738

# hacer pipeline
# parametros: Normalizer, KNeighborsClassifier
exported_pipeline = make_pipeline(
    Normalizer(norm="l2"),
    KNeighborsClassifier(n_neighbors=5, p=2, weights="distance")
)
# Fix random state for all the steps in exported pipeline
set_param_recursive(exported_pipeline.steps, 'random_state', 42)

exported_pipeline.fit(training_features, training_target)
results = exported_pipeline.predict(testing_features)

# %%
from tpot import TPOTClassifier
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

digits = load_digits() # cargar datos

# dividir datos de entrenamiento y datos de prueba
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target,
                                                    train_size=0.75, test_size=0.25, random_state=42)

# crear TPOTClassifier pipeline 
tpot = TPOTClassifier(generations=5, population_size=50, verbosity=2, random_state=42)
tpot.fit(X_train, y_train) # entrenar/ajustar pipeline con datos de entrenamiento
print(tpot.score(X_test, y_test)) # metricas de evaluacion
tpot.export('tpot_digits_pipeline.py')
# Out:
# c:\Users\Diego\miniconda3\lib\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# Optimization Progress:   0%|          | 0/300 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.9844058928817294
#
# Generation 2 - Current best internal CV score: 0.9844058928817294
#
# Generation 3 - Current best internal CV score: 0.9844058928817294
#
# Generation 4 - Current best internal CV score: 0.9844058928817294
#
# Generation 5 - Current best internal CV score: 0.9866363761531047
#
# Best pipeline: KNeighborsClassifier(input_matrix, n_neighbors=2, p=2, weights=distance)
# 0.9822222222222222
