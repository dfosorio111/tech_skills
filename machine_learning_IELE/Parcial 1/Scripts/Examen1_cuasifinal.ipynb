# %% [markdown]
# # Examen 1 de Machine Learning
#
# ### Presentado por:
#     - Diego Osorio, código:201513417
#     - Jaime Roberto Muñoz, código:200027408

# %% [markdown]
# # Se importan las librerías que se requieran

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'


import warnings
import math as m
warnings.filterwarnings('ignore')
import numpy as np
import missingno as msn
import pandas as pd   
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from imblearn.over_sampling import SMOTE
import itertools
import seaborn as sb
import time
tiempo=time.time()

from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc, precision_recall_curve
start_time = time.time()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0 seconds ---

# %% [markdown]
# # Introducción

# %% [markdown]
# Para encontrar el emjor modelo posible que permita predecircon una muy buena precisión las etiquetas con base en los datos proporcionados, seguiremos los siguientes pasos:
# - 1-Definir unas funciones auxiliares que nos ayudaran en el proceso de preparación de los datos y selección de variables
# - 2-Cargar los datos
# - 3-Análisis exploratorio y preparación de los datos
# - 4-Selección de variables
# - 5-Ajuste de modelos y selección del mejor modelo

# %% [markdown]
# # 1 .Funciones auxiliares
#
# Se definen funciones auxiliares para estandarizar, categorizar variables continuas y calcular el IV y el WoE de las variables categorizadas.   Varias de estas funciones son tomadas de del material de curso Machine Learning del profesor Fernando Lozamo.

# %%
# Función para estandarizar las variables continuas
def estandarizacion(df):
    return df.apply(lambda x: (x-x.mean())/x.std(), axis=0)

# Cálculo de IV #Tomada del material del curso Machine Learning Profesor Fernando Lozano.
def calc_iv(df, feature, target, pr=False):
    lst = []
    df[feature] = df[feature].fillna("NULL")

    for i in range(df[feature].nunique()):
        val = list(df[feature].unique())[i]
        lst.append([feature,                                                        # Variable
                    val,                                                            # Value
                    df[df[feature] == val].count()[feature],                        # All
                    df[(df[feature] == val) & (df[target] == 0)].count()[feature],  # Good (think: Fraud == 0)
                    df[(df[feature] == val) & (df[target] == 1)].count()[feature]]) # Bad (think: Fraud == 1)

    data = pd.DataFrame(lst, columns=['Variable', 'Value', 'All', 'Good', 'Bad'])
    data['Share'] = data['All'] / data['All'].sum()
    data['Bad Rate'] = data['Bad'] / data['All']
    data['Distribution Good'] = (data['All'] - data['Bad']) / (data['All'].sum() - data['Bad'].sum())
    data['Distribution Bad'] = data['Bad'] / data['Bad'].sum()
    data['WoE'] = np.log(data['Distribution Good'] / data['Distribution Bad'])
    
    data = data.replace({'WoE': {np.inf: 0, -np.inf: 0}})

    data['IV'] = data['WoE'] * (data['Distribution Good'] - data['Distribution Bad'])

    data = data.sort_values(by=['Variable', 'Value'], ascending=[True, True])
    data.index = range(len(data.index))

    if pr:
        print(data)
        print('IV = ', data['IV'].sum())

    iv = data['IV'].sum()
    print('El IV de esta variable es:',iv)
    print(df[feature].value_counts())
    return iv, data

# Matriz de Confusión  #Tomada del material del curso Machine Learning Profesor Fernando Lozano.
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Etiqueta')
    plt.xlabel('Predicción')
    
# Codificación One-Hot #Tomada del material del curso Machine Learning Profesor Fernando Lozano.
def convert_dummy(df, feature,rank=0):
    pos = pd.get_dummies(df[feature], prefix=feature)
    mode = df[feature].value_counts().index[rank]
    biggest = feature + '_' + str(mode)
    pos.drop([biggest],axis=1,inplace=True)
    df.drop([feature],axis=1,inplace=True)
    df=df.join(pos)
    return df

def convert_dummy2(df):
    pd.get_dummies(df, drop_first=True)
    return df

#Tomada del material del curso Machine Learning Profesor Fernando Lozano.
def get_category(df, col, binsnum, labels, prefijo, qcut = False):
    if qcut:
        localdf = pd.qcut(df[col], q = binsnum, labels = labels) # quantile cut
    else:
        localdf = pd.cut(df[col], bins = binsnum, labels = labels) # equal-length cut
        
    localdf = pd.DataFrame(localdf)
    name = prefijo + '_' + col
    localdf[name] = localdf[col]
    df = df.join(localdf[name])
    df[name] = df[name].astype(object)
    return df

# %% [markdown]
# ### Paso 2: Cargue de los datos

# %%
from pathlib import Path
d = Path().resolve().parent
str(d)
# Out:
# 'C:\\Users\\Acer\\Documents\\Doctorado\\Machine Learning'

# %%
#Se cargan las variables descriptoras
Xdata = pd.read_csv("xtrain.txt", header=None, sep='\s+')
Xdata.head(10)
# Out:
#         0         1          2          3         4         5        6   \
# 0  40572.0   725.331  250.71401  206.47193  1.214276  0.567264  40900.0
# 1  38180.0   740.017  272.92339  178.76282  1.526735  0.755635  38709.0
# 2  46827.0   808.608  300.96747  198.95893  1.512712  0.750329  47295.0
# 3  72058.0  1035.943  397.71702  233.41022  1.703940  0.809677  73724.0
# 4  80886.0  1136.801  391.65449  263.80113  1.484658  0.739136  82299.0
# 5  83773.0  1134.941  447.32256  242.46108  1.844925  0.840361  86024.0
# 6  41908.0   781.763  293.41596  182.57394  1.607108  0.782830  42480.0
# 7  39461.0   737.832  282.58806  178.47954  1.583308  0.775303  39855.0
# 8  62236.0   992.987  412.92287  193.36530  2.135455  0.883578  62840.0
# 9  94940.0  1183.102  463.50501  262.80779  1.763665  0.823717  95985.0
#
#           7         8         9         10        11        12        13  \
# 0  227.28369  0.767479  0.991980  0.969089  0.906546  0.006179  0.002574
# 1  220.48194  0.718669  0.986334  0.876118  0.807853  0.007148  0.001878
# 2  244.17614  0.781766  0.990105  0.899974  0.811304  0.006427  0.001718
# 3  302.89783  0.764541  0.977402  0.843763  0.761591  0.005519  0.001145
# 4  320.91627  0.719492  0.982831  0.786528  0.819386  0.004842  0.001346
# 5  326.59317  0.784237  0.973833  0.817273  0.730107  0.005340  0.000936
# 6  230.99550  0.714556  0.986535  0.861701  0.787263  0.007001  0.001659
# 7  224.15019  0.777863  0.990114  0.910884  0.793205  0.007161  0.001749
# 8  281.49838  0.831765  0.990388  0.793167  0.681721  0.006635  0.000884
# 9  347.67997  0.668366  0.989113  0.852344  0.750111  0.004882  0.000953
#
#          14        15
# 0  0.821825  0.997923
# 1  0.652626  0.996387
# 2  0.658214  0.995688
# 3  0.580021  0.988322
# 4  0.671394  0.996790
# 5  0.533056  0.983448
# 6  0.619783  0.996058
# 7  0.629174  0.996176
# 8  0.464744  0.992440
# 9  0.562666  0.992354

# %%
#Se carganlas etiquetas
Ydata = pd.read_csv("ytrain.txt", header=None)
Ydata.head(10)
# Out:
#      0
# 0  1.0
# 1  0.0
# 2  0.0
# 3  1.0
# 4  1.0
# 5  1.0
# 6  0.0
# 7  0.0
# 8  0.0
# 9  1.0

# %% [markdown]
# ## Paso 3. Análisis exploratorio y preparación de los datos
#
#
# El análisis exploratiorio tiene por objetivo saber como son las distribuciones de las variables descriptoras y además determinar si las clases que se pretenden identificar están balanceadas.   Así mismo, se revisa si existen valores perdidos, se estandarizan las variables de tal manera que tengan media = 0 y varianza = 1, y se revisa la correlación exitente entre las variables.
#
# Dado que las variables de este problema no se pueden poner en contexto, es por ejemplo complicado saber si dos variables que tienen una correlación alta están brindando la misma información, por lo que una de ellas sería redundante o si por el contrario a pesar de estar correlacionadas miden cosas distintas.
#
# Finalmente se hacen los histogramas de cada variable para saber como son sus distribuciones, lo que será útil al momento de tener que realizar transformación de variables.

# %%
#Se revisa si las clases están balanceadas
Ydata[0].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %% [markdown]
# El gráfico anterior muestra que los datos se encuentran balanceados pues cada categoría de la etiqueta tiene el 50% de los datos.
#
# Por otro lado en la grafica siguiente no se encuentran valores perdidos en los datos, que se ven representados en la gráfica como espacios en blanco.  Como se puede observar no existen.

# %%
msn.matrix(Xdata)
# Out:
# <AxesSubplot:>

# %% [markdown]
# El siguiente gráfico es un mapa de calor donde se muestran las correlaciones entre las variables, las correlaciones más altas a aparecen en azul oscuro o blanco.  Se puede observar que las variables 0, 1,2,3,6 y 12 se encuentran muy correlacionadas junto con la 14, 13 11 y 10; también la 15 con la 10.
#
# Desafortunadamente al no tener estas variables contexto, no podemos saber, como se dijo anteriormente si las variables altamente correlacionadas son redundantes o no.

# %%
correl = Xdata.corr()
rcParams['figure.figsize'] = 11.7,8.27
sb.heatmap(correl, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Debido a las diferencia dimensionales entre las variables, que se evidencia disimiltud en la magnitud de valores que toman, Se procede a estandarízar las variables continuas, para ello se hace una función Estandarización, según lo sugiere el Libro Elements of Statistical Learning, páginas 398-400.

# %%
XdataEst = estandarizacion(Xdata)
XdataEst.head(10)
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.549056 -0.774288 -0.962352 -0.070251 -1.463149 -1.856969 -0.555827
# 1 -0.626380 -0.707437 -0.710874 -0.662114 -0.291320  0.018311 -0.625590
# 2 -0.346858 -0.395211 -0.393330 -0.230728 -0.343911 -0.034514 -0.352208
# 3  0.468754  0.639619  0.702171  0.505147  0.373264  0.556315  0.489303
# 4  0.754127  1.098725  0.633525  1.154292 -0.449122 -0.145939  0.762335
# 5  0.847451  1.090258  1.263857  0.698472  0.902008  0.861776  0.880941
# 6 -0.505869 -0.517409 -0.478836 -0.580709  0.010107  0.289040 -0.505519
# 7 -0.584970 -0.717383 -0.601441 -0.668165 -0.079150  0.214111 -0.589101
# 8  0.151250  0.444083  0.874348 -0.350207  1.991597  1.292013  0.142752
# 9  1.208434  1.309487  1.447092  1.133075  0.597255  0.696084  1.198103
#
#          7         8         9         10        11        12        13  \
# 0 -0.597450  0.358633  1.039852  1.672519  1.660089 -0.142959  1.513182
# 1 -0.708909 -0.595637 -0.088408  0.178511  0.183947  0.714476  0.396986
# 2 -0.320637  0.637957  0.665042  0.561877  0.235567  0.076289  0.139872
# 3  0.641623  0.301199 -1.873106 -0.341414 -0.507984 -0.727132 -0.777332
# 4  0.936887 -0.579545 -0.788368 -1.261142  0.356450 -1.326585 -0.455232
# 5  1.029914  0.686271 -2.586312 -0.767084 -0.978898 -0.886170 -1.113085
# 6 -0.536625 -0.676044 -0.048263 -0.053156 -0.124015  0.584466  0.045846
# 7 -0.648798  0.561655  0.666940  0.737187 -0.035144  0.725861  0.189564
# 8  0.290955  1.615478  0.721716 -1.154468 -1.702592  0.259989 -1.196369
# 9  1.375459 -1.579100  0.466869 -0.203524 -0.679701 -1.291160 -1.085040
#
#          14        15
# 0  1.717682  0.706257
# 1  0.142015  0.380515
# 2  0.194054  0.232319
# 3 -0.534120 -1.330355
# 4  0.316787  0.466011
# 5 -0.971489 -2.364180
# 6 -0.163840  0.310671
# 7 -0.076387  0.335683
# 8 -1.607642 -0.456721
# 9 -0.695744 -0.474959

# %% [markdown]
# Creamos un dataframe que contiene las variables descriptoras estandarizadas y la variable de respuesta llamada Etiqueta.

# %%
df=XdataEst
df['Etiqueta']=Ydata[0]
df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.549056 -0.774288 -0.962352 -0.070251 -1.463149 -1.856969 -0.555827
# 1    -0.626380 -0.707437 -0.710874 -0.662114 -0.291320  0.018311 -0.625590
# 2    -0.346858 -0.395211 -0.393330 -0.230728 -0.343911 -0.034514 -0.352208
# 3     0.468754  0.639619  0.702171  0.505147  0.373264  0.556315  0.489303
# 4     0.754127  1.098725  0.633525  1.154292 -0.449122 -0.145939  0.762335
# ...        ...       ...       ...       ...       ...       ...       ...
# 8995  0.093613  0.378953  0.780598 -0.405406  1.937320  1.275080  0.090056
# 8996  0.437172  0.831203  0.699108  0.410649  0.492297  0.632684  0.449248
# 8997 -0.626638 -0.833696 -0.910054 -0.410440 -0.991603 -0.877504 -0.632690
# 8998 -0.081528  0.100921  0.494164 -0.520546  1.656873  1.181195 -0.088059
# 8999 -0.527204 -0.658926 -0.619651 -0.481485 -0.388562 -0.080836 -0.532902
#
#              7         8         9        10        11        12        13  \
# 0    -0.597450  0.358633  1.039852  1.672519  1.660089 -0.142959  1.513182
# 1    -0.708909 -0.595637 -0.088408  0.178511  0.183947  0.714476  0.396986
# 2    -0.320637  0.637957  0.665042  0.561877  0.235567  0.076289  0.139872
# 3     0.641623  0.301199 -1.873106 -0.341414 -0.507984 -0.727132 -0.777332
# 4     0.936887 -0.579545 -0.788368 -1.261142  0.356450 -1.326585 -0.455232
# ...        ...       ...       ...       ...       ...       ...       ...
# 8995  0.224398 -1.354410  0.251748 -1.154973 -1.644089  0.311964 -1.150740
# 8996  0.607859 -1.005722 -1.176671 -1.549225 -0.577769 -0.663361 -0.798523
# 8997 -0.709287 -0.098565  1.012028  1.293162  1.015027  0.307970  1.062198
# 8998  0.015889  0.988480  0.643806 -0.701157 -1.461935  0.488353 -0.997309
# 8999 -0.566550  1.321161  0.856331  0.881030  0.299936  0.416787  0.367080
#
#             14        15  Etiqueta
# 0     1.717682  0.706257       1.0
# 1     0.142015  0.380515       0.0
# 2     0.194054  0.232319       0.0
# 3    -0.534120 -1.330355       1.0
# 4     0.316787  0.466011       1.0
# ...        ...       ...       ...
# 8995 -1.557836  0.522777       0.0
# 8996 -0.600100 -0.033861       1.0
# 8997  1.006812  0.927206       1.0
# 8998 -1.400935  0.379009       0.0
# 8999  0.259257  0.799031       0.0
#
# [9000 rows x 17 columns]

# %% [markdown]
# Renobramos las variables para facilitar su manejo

# %%
df.rename(columns={0:'Var_0',1:'Var_1', 2:'Var_2',3:'Var_3',4:'Var_4',5:'Var_5',6:'Var_6',7:'Var_7',8:'Var_8',
                   9:'Var_9',10:'Var_10',11:'Var_11',12:'Var_12',13:'Var_13',14:'Var_14',15:'Var_15'},inplace=True)
df.head(10)
# Out:
#       Var_0     Var_1     Var_2     Var_3     Var_4     Var_5     Var_6  \
# 0 -0.549056 -0.774288 -0.962352 -0.070251 -1.463149 -1.856969 -0.555827
# 1 -0.626380 -0.707437 -0.710874 -0.662114 -0.291320  0.018311 -0.625590
# 2 -0.346858 -0.395211 -0.393330 -0.230728 -0.343911 -0.034514 -0.352208
# 3  0.468754  0.639619  0.702171  0.505147  0.373264  0.556315  0.489303
# 4  0.754127  1.098725  0.633525  1.154292 -0.449122 -0.145939  0.762335
# 5  0.847451  1.090258  1.263857  0.698472  0.902008  0.861776  0.880941
# 6 -0.505869 -0.517409 -0.478836 -0.580709  0.010107  0.289040 -0.505519
# 7 -0.584970 -0.717383 -0.601441 -0.668165 -0.079150  0.214111 -0.589101
# 8  0.151250  0.444083  0.874348 -0.350207  1.991597  1.292013  0.142752
# 9  1.208434  1.309487  1.447092  1.133075  0.597255  0.696084  1.198103
#
#       Var_7     Var_8     Var_9    Var_10    Var_11    Var_12    Var_13  \
# 0 -0.597450  0.358633  1.039852  1.672519  1.660089 -0.142959  1.513182
# 1 -0.708909 -0.595637 -0.088408  0.178511  0.183947  0.714476  0.396986
# 2 -0.320637  0.637957  0.665042  0.561877  0.235567  0.076289  0.139872
# 3  0.641623  0.301199 -1.873106 -0.341414 -0.507984 -0.727132 -0.777332
# 4  0.936887 -0.579545 -0.788368 -1.261142  0.356450 -1.326585 -0.455232
# 5  1.029914  0.686271 -2.586312 -0.767084 -0.978898 -0.886170 -1.113085
# 6 -0.536625 -0.676044 -0.048263 -0.053156 -0.124015  0.584466  0.045846
# 7 -0.648798  0.561655  0.666940  0.737187 -0.035144  0.725861  0.189564
# 8  0.290955  1.615478  0.721716 -1.154468 -1.702592  0.259989 -1.196369
# 9  1.375459 -1.579100  0.466869 -0.203524 -0.679701 -1.291160 -1.085040
#
#      Var_14    Var_15  Etiqueta
# 0  1.717682  0.706257       1.0
# 1  0.142015  0.380515       0.0
# 2  0.194054  0.232319       0.0
# 3 -0.534120 -1.330355       1.0
# 4  0.316787  0.466011       1.0
# 5 -0.971489 -2.364180       1.0
# 6 -0.163840  0.310671       0.0
# 7 -0.076387  0.335683       0.0
# 8 -1.607642 -0.456721       0.0
# 9 -0.695744 -0.474959       1.0

# %%
namelist = ['Var_0', 'Var_1','Var_2','Var_3','Var_4','Var_5','Var_6','Var_7','Var_8','Var_9','Var_10','Var_11','Var_12',
           'Var_13','Var_14','Var_15']
for var in namelist:
    print('Análisis variable', var)
    df[var] = df[var].astype(object)
    print(df[var].value_counts(bins=10,sort=False))
# Out:
# Análisis variable Var_0
# (-1.2089999999999999, -0.454]    3105
# (-0.454, 0.293]                  3592
# (0.293, 1.04]                    1739
# (1.04, 1.787]                     130
# (1.787, 2.533]                     19
# (2.533, 3.28]                     105
# (3.28, 4.027]                     169
# (4.027, 4.774]                    104
# (4.774, 5.52]                      30
# (5.52, 6.267]                       7
# Name: Var_0, dtype: int64
# Análisis variable Var_1
# (-1.6949999999999998, -1.052]     851
# (-1.052, -0.416]                 2802
# (-0.416, 0.22]                   2098
# (0.22, 0.856]                    2021
# (0.856, 1.492]                    749
# (1.492, 2.128]                     55
# (2.128, 2.764]                     97
# (2.764, 3.4]                      202
# (3.4, 4.036]                      103
# (4.036, 4.672]                     22
# Name: Var_1, dtype: int64
# Análisis variable Var_2
# (-1.73, -1.094]     1191
# (-1.094, -0.466]    2135
# (-0.466, 0.161]     1831
# (0.161, 0.789]      2352
# (0.789, 1.417]       996
# (1.417, 2.045]        92
# (2.045, 2.673]       121
# (2.673, 3.301]       166
# (3.301, 3.929]        97
# (3.929, 4.557]        19
# Name: Var_2, dtype: int64
# Análisis variable Var_3
# (-1.8719999999999999, -1.142]     603
# (-1.142, -0.421]                 2425
# (-0.421, 0.3]                    3503
# (0.3, 1.022]                     1727
# (1.022, 1.743]                    306
# (1.743, 2.464]                      6
# (2.464, 3.185]                    118
# (3.185, 3.907]                    225
# (3.907, 4.628]                     75
# (4.628, 5.349]                     12
# Name: Var_3, dtype: int64
# Análisis variable Var_4
# (-2.1799999999999997, -1.646]     230
# (-1.646, -1.119]                 1188
# (-1.119, -0.592]                  997
# (-0.592, -0.0651]                2136
# (-0.0651, 0.462]                 1952
# (0.462, 0.989]                    998
# (0.989, 1.516]                    572
# (1.516, 2.043]                    642
# (2.043, 2.57]                     256
# (2.57, 3.097]                      29
# Name: Var_4, dtype: int64
# Análisis variable Var_5
# (-5.332000000000001, -4.635]       3
# (-4.635, -3.946]                  12
# (-3.946, -3.256]                  21
# (-3.256, -2.567]                 124
# (-2.567, -1.878]                 433
# (-1.878, -1.188]                 741
# (-1.188, -0.499]                 690
# (-0.499, 0.19]                  2351
# (0.19, 0.88]                    3078
# (0.88, 1.569]                   1547
# Name: Var_5, dtype: int64
# Análisis variable Var_6
# (-1.208, -0.446]    3208
# (-0.446, 0.308]     3517
# (0.308, 1.062]      1723
# (1.062, 1.816]       119
# (1.816, 2.569]        21
# (2.569, 3.323]       116
# (3.323, 4.077]       170
# (4.077, 4.831]        92
# (4.831, 5.585]        29
# (5.585, 6.338]         5
# Name: Var_6, dtype: int64
# Análisis variable Var_7
# (-1.6869999999999998, -1.017]     790
# (-1.017, -0.354]                 3037
# (-0.354, 0.309]                  2516
# (0.309, 0.972]                   1817
# (0.972, 1.635]                    398
# (1.635, 2.298]                     14
# (2.298, 2.961]                     95
# (2.961, 3.624]                    215
# (3.624, 4.287]                     99
# (4.287, 4.95]                      19
# Name: Var_7, dtype: int64
# Análisis variable Var_8
# (-3.796, -3.182]      35
# (-3.182, -2.574]     189
# (-2.574, -1.966]     254
# (-1.966, -1.358]     394
# (-1.358, -0.75]     1069
# (-0.75, -0.143]     1396
# (-0.143, 0.465]     2079
# (0.465, 1.073]      2681
# (1.073, 1.681]       874
# (1.681, 2.289]        29
# Name: Var_8, dtype: int64
# Análisis variable Var_9
# (-13.51, -11.986]        1
# (-11.986, -10.479]       0
# (-10.479, -8.972]        0
# (-8.972, -7.465]         5
# (-7.465, -5.957]        12
# (-5.957, -4.45]         39
# (-4.45, -2.943]         98
# (-2.943, -1.436]       535
# (-1.436, 0.0715]      3010
# (0.0715, 1.579]       5300
# Name: Var_9, dtype: int64
# Análisis variable Var_10
# (-4.961, -4.262]       6
# (-4.262, -3.57]       12
# (-3.57, -2.879]       32
# (-2.879, -2.187]      88
# (-2.187, -1.496]     436
# (-1.496, -0.804]    1510
# (-0.804, -0.113]    1831
# (-0.113, 0.579]     2413
# (0.579, 1.27]       1565
# (1.27, 1.962]       1107
# Name: Var_10, dtype: int64
# Análisis variable Var_11
# (-2.324, -1.799]     185
# (-1.799, -1.281]     940
# (-1.281, -0.762]     844
# (-0.762, -0.244]    1684
# (-0.244, 0.275]     2181
# (0.275, 0.794]      1314
# (0.794, 1.312]       622
# (1.312, 1.831]       871
# (1.831, 2.349]       329
# (2.349, 2.868]        30
# Name: Var_11, dtype: int64
# Análisis variable Var_12
# (-3.161, -2.474]     290
# (-2.474, -1.795]     143
# (-1.795, -1.116]     457
# (-1.116, -0.437]    1807
# (-0.437, 0.242]     2636
# (0.242, 0.921]      2484
# (0.921, 1.6]         555
# (1.6, 2.279]         529
# (2.279, 2.958]        94
# (2.958, 3.637]         5
# Name: Var_12, dtype: int64
# Análisis variable Var_13
# (-1.7149999999999999, -1.212]     395
# (-1.212, -0.715]                 2575
# (-0.715, -0.218]                 1497
# (-0.218, 0.279]                  1522
# (0.279, 0.776]                    799
# (0.776, 1.273]                    793
# (1.273, 1.77]                     889
# (1.77, 2.267]                     416
# (2.267, 2.764]                    105
# (2.764, 3.261]                      9
# Name: Var_13, dtype: int64
# Análisis variable Var_14
# (-2.121, -1.589]      366
# (-1.589, -1.063]     1048
# (-1.063, -0.537]     1267
# (-0.537, -0.0118]    2112
# (-0.0118, 0.514]     1876
# (0.514, 1.039]        765
# (1.039, 1.565]        685
# (1.565, 2.091]        679
# (2.091, 2.616]        179
# (2.616, 3.142]         23
# Name: Var_14, dtype: int64
# Análisis variable Var_15
# (-9.962, -8.846]        3
# (-8.846, -7.742]        3
# (-7.742, -6.638]        9
# (-6.638, -5.534]       14
# (-5.534, -4.43]        33
# (-4.43, -3.326]        64
# (-3.326, -2.222]      185
# (-2.222, -1.118]      649
# (-1.118, -0.0138]    2285
# (-0.0138, 1.09]      5755
# Name: Var_15, dtype: int64

# %%
nrow=8
ncol=2
fig, axes = plt.subplots(nrow, ncol)

# Para generar histogramas de cada variable##
plt.rcParams["figure.figsize"] = (12,12)
contador=0
for f in range(nrow):
    for c in range(ncol):
        df[namelist[contador]].plot(kind='hist', bins= 30, density=True, ax=axes[f,c])
        axes[f,c].title.set_text(namelist[contador])
        contador=contador+1
#Espaciando
fig.tight_layout()
plt.show()

# %% [markdown]
# Los histogramas permiten observar el comportamiento de las variables, y esto permite de ser necesario encontrar las transformaciones más adecuadas en caso de requerirse.
#
# Los histogramas en este caso nos permiten observar lo siguiente:
#    - Var_0: Muestra una distribución sesgada por derecha.
#    - Var_1: Muestra bimodal con sesgo postivo.
#    - Var_2: Distribución multimodal con sesgo positivo.
#    - Var_3: Distribución multimodal con sesgo positivo.
#    - Var_4: Distribución muestra tres modas y es ligeramente sesgada por derecha.
#    - Var_5: Distribución con sesgo negativo.
#    - Var 6: Distribución sesgada por derecha.
#    - Var 7: Distribución con sesgo Positivo.
#    - Var 8: Distribución con sesgo negativo y dos modas.
#    - Var 9: Distribución con sesgo negativo.
#    - Var 10: Distribución con sesgo negativo y dos modas.
#    - Var 11: Distribución más o menos simétrica con tres modas.
#    - Var 12: Distribución más o menos simétrica con tres modas.
#    - Var 13: Distribución con sesgo postivo multimodal.
#    - Var 14: Distribución más o menos simétrica multimodal.
#    - var 15: Distribución con sesgo negativo.
#
#  A continuacion categorizamos las todas variables originales en 3 grupos, y de acuerdo con los resultados aumentaremos o disminuiremos la cantidad de categorías, buscando como categorizar de menor manera las variables continuas y al mismo tiempo mejorar su poder predictivo, con el fin de ayudar a que el modelo sea mejor clasificando.  A cada intento le dimos un prefijo diferente para poder diferenciarlos posteriormente.
#
# Es importante mencionar que a las variables obtenidas se les coloca el prefijo gp.

# %% [markdown]
# ## Paso 4. Selección de variables con IV y WoE
#
#
# Teniendo en cuenta que todas las variables son continuas y ya tenieénolas estandarizadas, vamos a revisar su aporte en la clasificación usando IV (information Value) y Weight of evidence (WoE).
#
# WoE e IV pueden ser usados para cuantificar y entender el poder predictivo de una variable con la desventaja que es una análisis individual por variable, es decir tiene en cuenta interacciones entre las variables.  A continuación se muestra como se definen estos valores.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Tomado de:https://medium.com/mlearning-ai/weight-of-evidence-woe-and-information-value-iv-how-to-use-it-in-eda-and-model-building-3b3b98efe0e8
#
# Dependiento el valor que tomen se determina su poder predictivo con base el IV y si la variable se encuentra bien categorizda con el WoE.  Si una variable está bien categorizada su WoE decrece o crece monotónicamente entre las categorías adyacentes.
#
# Los valores de referencia que se toman en cuenta son:
#
# ![image-3.png](attachment:image-3.png)
#
# Tomado de:https://medium.com/mlearning-ai/weight-of-evidence-woe-and-information-value-iv-how-to-use-it-in-eda-and-model-building-3b3b98efe0e8
#
# Buscamos variables que cuyo IV este en el rango $0.1 \leq IV \leq 0.5$ que pues son las que tienen un poder predictivo medio a fuerte.  Las que están por debajo de este rango las analizaremos para ver si con una transformación y/o creando una interaccion pueden mejorar.
#
# Las que tienen un IV superior a 0.5 son sospechosas y también las analizaremos para ver si una transformación y/o una interacción mejora su índice IV.  Este proceso se hace un poco más complicado al no tener variables sin contexto, pero exploraremos posibilidades teniendo en cuenta el tiempo de ejecución de los modelos y el plazo de entrega del exámen, el objetivo obtener el mejor modelo posible.
#
# En primera instancia categorizamos todas las variables en tres categorías Alta, Media y Baja y se hace el análisis del WoE y el IV.  A las variables que se generan de este primer análisis se les antepone el prefijo gp.

# %%
#Se crea la tabla IV
ivtable=pd.DataFrame(df.columns,columns=['variable'])
ivtable['IV']=None
namelist = ['Var_0', 'Var_1','Var_2','Var_3','Var_4','Var_5','Var_6','Var_7','Var_8','Var_9','Var_10','Var_11','Var_12',
           'Var_13','Var_14','Var_15']

for i in namelist:
    ivtable.drop(ivtable[ivtable['variable'] == i].index, inplace=True)

ivtable.head()
# Out:
#     variable    IV
# 16  Etiqueta  None

# %%
# Se categorizan las variables y se revisa si la categorización es adecuada y su poder de predicción de acuerdo con lo ya explicado.
for var in namelist:
    print('Variable:',var)
    print('')
    df = get_category(df, var, 3, ["Bajo", "Medio", "Alto"], 'gp', qcut = True)
    iv, data = calc_iv(df,'gp_'+var,'Etiqueta')
    ivtable.loc[ivtable['variable']== 'gp_'+var,'IV']=iv
    print('')
    print(data)
    print('')
# Out:
# Variable: Var_0
#
# El IV de esta variable es: 1.6995068037058123
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_0, dtype: int64
#
#    Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_0   Alto  3000   342  2658  0.333333  0.886000           0.075949
# 1  gp_Var_0   Bajo  3000  1721  1279  0.333333  0.426333           0.382190
# 2  gp_Var_0  Medio  3000  2440   560  0.333333  0.186667           0.541861
#
#    Distribution Bad       WoE        IV
# 0          0.591061 -2.051852  1.056932
# 1          0.284412  0.295494  0.028893
# 2          0.124527  1.470483  0.613682
#
# Variable: Var_1
#
# El IV de esta variable es: 1.5674273530955616
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_1, dtype: int64
#
#    Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_1   Alto  3000   426  2574  0.333333  0.858000           0.094604
# 1  gp_Var_1   Bajo  3000  1583  1417  0.333333  0.472333           0.351543
# 2  gp_Var_1  Medio  3000  2494   506  0.333333  0.168667           0.553853
#
#    Distribution Bad       WoE        IV
# 0          0.572382 -1.800110  0.860053
# 1          0.315099  0.109446  0.003989
# 2          0.112519  1.593773  0.703386
#
# Variable: Var_2
#
# El IV de esta variable es: 0.6035396055999382
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_2, dtype: int64
#
#    Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_2   Alto  3000   858  2142  0.333333  0.714000           0.190540
# 1  gp_Var_2   Bajo  3000  1421  1579  0.333333  0.526333           0.315567
# 2  gp_Var_2  Medio  3000  2224   776  0.333333  0.258667           0.493893
#
#    Distribution Bad       WoE        IV
# 0          0.476318 -0.916224  0.261837
# 1          0.351123 -0.106764  0.003796
# 2          0.172559  1.051577  0.337907
#
# Variable: Var_3
#
# El IV de esta variable es: 4.654502220676227
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_3, dtype: int64
#
#    Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_3   Alto  3000    28  2972  0.333333  0.990667           0.006218
# 1  gp_Var_3   Bajo  3000  2814   186  0.333333  0.062000           0.624917
# 2  gp_Var_3  Medio  3000  1661  1339  0.333333  0.446333           0.368865
#
#    Distribution Bad       WoE        IV
# 0          0.660885 -4.666119  3.054754
# 1          0.041361  2.715282  1.584519
# 2          0.297754  0.214163  0.015229
#
# Variable: Var_4
#
# El IV de esta variable es: 0.32552957533190624
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_4, dtype: int64
#
#    Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_4   Alto  3000  1835  1165  0.333333  0.388333           0.407506
# 1  gp_Var_4   Bajo  3000   910  2090  0.333333  0.696667           0.202087
# 2  gp_Var_4  Medio  3000  1758  1242  0.333333  0.414000           0.390406
#
#    Distribution Bad       WoE        IV
# 0          0.259062  0.452990  0.067244
# 1          0.464754 -0.832808  0.218751
# 2          0.276184  0.346120  0.039535
#
# Variable: Var_5
#
# El IV de esta variable es: 0.32552957533190624
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_5, dtype: int64
#
#    Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_5   Alto  3000  1835  1165  0.333333  0.388333           0.407506
# 1  gp_Var_5   Bajo  3000   910  2090  0.333333  0.696667           0.202087
# 2  gp_Var_5  Medio  3000  1758  1242  0.333333  0.414000           0.390406
#
#    Distribution Bad       WoE        IV
# 0          0.259062  0.452990  0.067244
# 1          0.464754 -0.832808  0.218751
# 2          0.276184  0.346120  0.039535
#
# Variable: Var_6
#
# El IV de esta variable es: 1.7087529430179402
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_6, dtype: int64
#
#    Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_6   Alto  3000   342  2658  0.333333  0.886000           0.075949
# 1  gp_Var_6   Bajo  3000  1714  1286  0.333333  0.428667           0.380635
# 2  gp_Var_6  Medio  3000  2447   553  0.333333  0.184333           0.543416
#
#    Distribution Bad       WoE        IV
# 0          0.591061 -2.051852  1.056932
# 1          0.285968  0.285960  0.027071
# 2          0.122971  1.485927  0.624750
#
# Variable: Var_7
#
# El IV de esta variable es: 1.6995068037058123
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_7, dtype: int64
#
#    Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_7   Alto  3000   342  2658  0.333333  0.886000           0.075949
# 1  gp_Var_7   Bajo  3000  1721  1279  0.333333  0.426333           0.382190
# 2  gp_Var_7  Medio  3000  2440   560  0.333333  0.186667           0.541861
#
#    Distribution Bad       WoE        IV
# 0          0.591061 -2.051852  1.056932
# 1          0.284412  0.295494  0.028893
# 2          0.124527  1.470483  0.613682
#
# Variable: Var_8
#
# El IV de esta variable es: 0.3697188950783119
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_8, dtype: int64
#
#    Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_8   Alto  3000  1343  1657  0.333333  0.552333           0.298246
# 1  gp_Var_8   Bajo  3000  2108   892  0.333333  0.297333           0.468132
# 2  gp_Var_8  Medio  3000  1052  1948  0.333333  0.649333           0.233622
#
#    Distribution Bad       WoE        IV
# 0          0.368468 -0.211436  0.014848
# 1          0.198354  0.858695  0.231657
# 2          0.433178 -0.617443  0.123214
#
# Variable: Var_9
#
# El IV de esta variable es: 0.37592259910208053
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_9, dtype: int64
#
#    Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_9   Alto  3000  1159  1841  0.333333  0.613667           0.257384
# 1  gp_Var_9   Bajo  3000  1209  1791  0.333333  0.597000           0.268488
# 2  gp_Var_9  Medio  3000  2135   865  0.333333  0.288333           0.474128
#
#    Distribution Bad       WoE        IV
# 0          0.409384 -0.464085  0.070541
# 1          0.398266 -0.394314  0.051173
# 2          0.192350  0.902159  0.254208
#
# Variable: Var_10
#
# El IV de esta variable es: 0.020317661024344208
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_10, dtype: int64
#
#     Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_10   Alto  3000  1351  1649  0.333333  0.549667           0.300022
# 1  gp_Var_10   Bajo  3000  1591  1409  0.333333  0.469667           0.353320
# 2  gp_Var_10  Medio  3000  1561  1439  0.333333  0.479667           0.346658
#
#    Distribution Bad       WoE        IV
# 0          0.366689 -0.200657  0.013377
# 1          0.313320  0.120149  0.004806
# 2          0.319991  0.080045  0.002135
#
# Variable: Var_11
#
# El IV de esta variable es: 0.3245974577765974
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_11, dtype: int64
#
#     Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_11   Alto  3000   910  2090  0.333333  0.696667           0.202087
# 1  gp_Var_11   Bajo  3000  1824  1176  0.333333  0.392000           0.405063
# 2  gp_Var_11  Medio  3000  1769  1231  0.333333  0.410333           0.392849
#
#    Distribution Bad       WoE        IV
# 0          0.464754 -0.832808  0.218751
# 1          0.261508  0.437580  0.062817
# 2          0.273738  0.361254  0.043029
#
# Variable: Var_12
#
# El IV de esta variable es: 4.987896402472154
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_12, dtype: int64
#
#     Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_12   Alto  3000  2841   159  0.333333     0.053           0.630913
# 1  gp_Var_12   Bajo  3000    21  2979  0.333333     0.993           0.004664
# 2  gp_Var_12  Medio  3000  1641  1359  0.333333     0.453           0.364424
#
#    Distribution Bad       WoE        IV
# 0          0.035357  2.881674  1.716198
# 1          0.662442 -4.956154  3.260049
# 2          0.302201  0.187223  0.011649
#
# Variable: Var_13
#
# El IV de esta variable es: 0.08215346025525734
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_13, dtype: int64
#
#     Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_13   Alto  3000  1336  1664  0.333333  0.554667           0.296691
# 1  gp_Var_13   Bajo  3000  1364  1636  0.333333  0.545333           0.302909
# 2  gp_Var_13  Medio  3000  1803  1197  0.333333  0.399000           0.400400
#
#    Distribution Bad       WoE        IV
# 0          0.370024 -0.220878  0.016198
# 1          0.363798 -0.183166  0.011153
# 2          0.266177  0.408300  0.054803
#
# Variable: Var_14
#
# El IV de esta variable es: 0.3245974577765974
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_14, dtype: int64
#
#     Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_14   Alto  3000   910  2090  0.333333  0.696667           0.202087
# 1  gp_Var_14   Bajo  3000  1824  1176  0.333333  0.392000           0.405063
# 2  gp_Var_14  Medio  3000  1769  1231  0.333333  0.410333           0.392849
#
#    Distribution Bad       WoE        IV
# 0          0.464754 -0.832808  0.218751
# 1          0.261508  0.437580  0.062817
# 2          0.273738  0.361254  0.043029
#
# Variable: Var_15
# El IV de esta variable es: 0.28369472785458594
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gp_Var_15, dtype: int64
#
#     Variable  Value   All  Good   Bad     Share  Bad Rate  Distribution Good  \
# 0  gp_Var_15   Alto  3000  1063  1937  0.333333  0.645667           0.236065
# 1  gp_Var_15   Bajo  3000  1425  1575  0.333333  0.525000           0.316456
# 2  gp_Var_15  Medio  3000  2015   985  0.333333  0.328333           0.447479
#
#    Distribution Bad       WoE        IV
# 0          0.430732 -0.601379  0.117068
# 1          0.350233 -0.101417  0.003426
# 2          0.219035  0.714399  0.163201

# %% [markdown]
# Analizando el IV y WoE podemos decir:
#
# - Las variables gp_Var_0, gp_Var_1, gp_Var_2, gp_Var_3,gp_Var_6, gp_Var_7, gp_Var_12; tienen un IV mayor a 0.5 lo que hace sospechosas, demasiado bueno para ser cierto.  El WoE de estas variables tiene el comportamiento monotónico deseado, excepto para la variable gp_Var_12.
#
# - Las variables: gp_Var_4, gp_Var_5, gp_Var_8, gp_Var_11; Hay que revisar la cantidad de categorías pues el WoE no es monotónico, es decir a medida que se deciende en el orden de las categorias no tiene una tendencia de descenso o ascenso, sino que aumenta y luego baja visceversa.
# - Las variables: gp_Var_9,  gp_Var_14, gp_Var_15; Tienen un IV que muestra un poder predictivo entre medio y fuerte.
# - Las variables: gp_Var_13 y gp_Var_10  tienen un poder predictivo debil o no tienen y un WoE monotónico que se puede observar al revisar su comportamiento en las categorías.
#
# Con base en lo anterior exploraremos cambiar la agrupación de las variables sospechosas al momento de categorizar IV > 0.5, exploraremos otras categorizaciones para aquellas cuyo WoE no fue monotónico y la creación de unas nuevas variables de interacción, por ejemplo entre Var_13 y Var_10 que por si solas no tiene un poder predictivo fuerte.  Agregamos a la lista de variables una interacción, Var_1310, que definieremos más adelante.

# %%
#Se crea la tabla IV
ivtable=pd.DataFrame(df.columns,columns=['variable'])
ivtable['IV']=None
namelist = ['Var_0', 'Var_1','Var_2','Var_3','Var_4','Var_5','Var_6','Var_7','Var_8','Var_9','Var_10','Var_11','Var_12',
           'Var_13','Var_14','Var_15', 'Var_1310']

for i in namelist:
    ivtable.drop(ivtable[ivtable['variable'] == i].index, inplace=True)

ivtable.head()
# Out:
#     variable    IV
# 16  Etiqueta  None
# 17  gp_Var_0  None
# 18  gp_Var_1  None
# 19  gp_Var_2  None
# 20  gp_Var_3  None

# %% [markdown]
# Para transformar las variables Var_13 y Var_10, se utilizó la escalera de Tukey que utiliza transformaciones de potencias.  Esta metodología es explicada en el libro: Tukey, J. W. (1977). Exploratory Data Analysis. Addison-Wesley, Reading, MA.
#
# La escalera es la que se muestra a continuación:
#
# ![image.png](attachment:image.png)
# Tomada de: https://onlinestatbook.com/2/transformations/tukey.html
#
# Hacia la izquierda se dice que se baja en la escalera y hacia la derecha se sube.  La variable sin transformar es $X^1$.
#
# Si la varible tiene una distribucion con sesgo negativo se baja y si tiene sesgo positivo se baja hasta que se llegue a una simetrización que se considere suficiente de la distribución.
#
# En nuestro caos la variable Var_13 tiene sesgo positivo y se baja hasta que $\lambda = -1$  y para Var_10 que tiene sesgo negativo se sube hasta que $\lambda = 2$.
#
# A continuación generamos variable Var_1310 que resulta de la interacción de las variables Var_13 y Var_10 transformadas como se acaba de explicar.  Luego exploramos como categorizar Var_1310 en 3 categorías y le anteponemos a la variable categórica creada el prefijo gpI1.

# %%
#Primero creamos la variable de la interacción entre Var_13 y Var10  que llamamos Var_1310

# La trasnformacion que se muestra a cotinuación se basa en la Escalera de Tukey.  Al tener Var_13 un sesgo positivo se baja
# en la escalera y se hace la transformación 1/Var_13 y al tener Var_10 un sesgo negativo se sube en la escalera y se transforma
# elevando la variable a cuadrado.

df['Var_1310'] = 1/df['Var_13']*(df['Var_10']*df['Var_10'])

#Ahora exploramos la categorización de esta nueva variable

df = get_category(df, 'Var_1310', 3, ["Bajo", "Medio", "Alto"], 'gpI1', qcut = True)
iv, data = calc_iv(df,'gpI1_Var_1310','Etiqueta')
ivtable.loc[ivtable['variable']== 'gpI1_'+var,'IV']=iv
print('')
print(data)
print('')
# Out:
# El IV de esta variable es: 0.12365258332422537
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gpI1_Var_1310, dtype: int64
#
#         Variable  Value   All  Good   Bad     Share  Bad Rate  \
# 0  gpI1_Var_1310   Alto  3000  1391  1609  0.333333  0.536333
# 1  gpI1_Var_1310   Bajo  3000  1862  1138  0.333333  0.379333
# 2  gpI1_Var_1310  Medio  3000  1250  1750  0.333333  0.583333
#
#    Distribution Good  Distribution Bad       WoE        IV
# 0           0.308905          0.357794 -0.146923  0.007183
# 1           0.413502          0.253058  0.491046  0.078786
# 2           0.277593          0.389148 -0.337806  0.037684

# %% [markdown]
# La variable categórica creada es gpI1_Var1310, observamos que el WoE obtenido no se comporta de manera monotónica, por lo anterior aumentamos las categorías, lo que también ayudará a aumentar el poder productivo de esta nueva variable de interacción. Hacemos de nuevo la categorización y le ponemos el prefijo a gpI2 a la nueva variable.

# %%
df = get_category(df, 'Var_1310', 4, ["Muy bajo", "Bajo", "Medio", "Alto"], 'gpI2', qcut = True)
iv, data = calc_iv(df,'gpI2_Var_1310','Etiqueta')
ivtable.loc[ivtable['variable']== 'gpI2_'+var,'IV']=iv
print('')
print(data)
print('')
# Out:
# El IV de esta variable es: 0.22072824101163868
# Alto        2250
# Muy bajo    2250
# Medio       2250
# Bajo        2250
# Name: gpI2_Var_1310, dtype: int64
#
#         Variable     Value   All  Good   Bad  Share  Bad Rate  \
# 0  gpI2_Var_1310      Alto  2250   861  1389   0.25  0.617333
# 1  gpI2_Var_1310      Bajo  2250   870  1380   0.25  0.613333
# 2  gpI2_Var_1310     Medio  2250  1347   903   0.25  0.401333
# 3  gpI2_Var_1310  Muy bajo  2250  1425   825   0.25  0.366667
#
#    Distribution Good  Distribution Bad       WoE        IV
# 0           0.191206          0.308873 -0.479578  0.056430
# 1           0.193205          0.306871 -0.462679  0.052591
# 2           0.299134          0.200801  0.398579  0.039194
# 3           0.316456          0.183456  0.545210  0.072513

# %% [markdown]
# En el resultado anterior, se puede observar que al aumentar a 4 categorías mejoro el IV a 0.22 y WoE crece monotónicamente por lo tanto usaremos gpI2_Var1310.

# %% [markdown]
# Dado que utilizaremos en algunos de nuestros modelos la variable de interacción, también analizaremos como se comportan las variables individuales Var_13 y Var_10 transformadas, con el objetivo de mantener el orden jerárquico, es decir que si está la interacción en el modelo incluir también las variables que interctuan individualmente.  A las variables Transformadas y categorizadas les ponemos el prefijo gpT

# %%
# Se crean las variables que interactuan haciendo las mismas transforaciones utilizadas para generar la interacción
df['Var_13T'] = 1/df['Var_13']
df['Var_10T'] = df['Var_10']*df['Var_10']

#Categorizamos y calculamos la IV para Var_13T
df = get_category(df, 'Var_13T', 3, ["Bajo", "Medio", "Alto"], 'gpT', qcut = True)
iv, data = calc_iv(df,'gpT_Var_13T','Etiqueta')
ivtable.loc[ivtable['variable']== 'gpT_'+var,'IV']=iv
print('')
print(data)
print('')

df = get_category(df, 'Var_10T', 3, ["Bajo", "Medio", "Alto"], 'gpT', qcut = True)
iv, data = calc_iv(df,'gpT_Var_10T','Etiqueta')
ivtable.loc[ivtable['variable']== 'gpT_'+var,'IV']=iv
print('')
print(data)
print('')
# Out:
# El IV de esta variable es: 0.15295834749971113
# Bajo     3001
# Alto     3000
# Medio    2999
# Name: gpT_Var_13T, dtype: int64
#
#       Variable  Value   All  Good   Bad     Share  Bad Rate  \
# 0  gpT_Var_13T   Alto  3000  1904  1096  0.333333  0.365333
# 1  gpT_Var_13T   Bajo  3001  1369  1632  0.333444  0.543819
# 2  gpT_Var_13T  Medio  2999  1230  1769  0.333222  0.589863
#
#    Distribution Good  Distribution Bad       WoE        IV
# 0           0.422829          0.243718  0.550956  0.098682
# 1           0.304020          0.362909 -0.177059  0.010427
# 2           0.273151          0.393373 -0.364734  0.043849
#
# El IV de esta variable es: 0.16992275875633533
# Alto     3000
# Medio    3000
# Bajo     3000
# Name: gpT_Var_10T, dtype: int64
#
#       Variable  Value   All  Good   Bad     Share  Bad Rate  \
# 0  gpT_Var_10T   Alto  3000  1121  1879  0.333333  0.626333
# 1  gpT_Var_10T   Bajo  3000  1512  1488  0.333333  0.496000
# 2  gpT_Var_10T  Medio  3000  1870  1130  0.333333  0.376667
#
#    Distribution Good  Distribution Bad       WoE        IV
# 0           0.248945          0.417834 -0.517852  0.087459
# 1           0.335776          0.330887  0.014667  0.000072
# 2           0.415279          0.251279  0.502387  0.082392

# %% [markdown]
# Las dos variables transformadas tienen un WoE Monotónico y un IV entre 0.1 y 0.3 que indica un poder predictivo medio.

# %%
#Se crea la tabla IV actualizada con la variable de interacción y las dos variables transformadas.
ivtable=pd.DataFrame(df.columns,columns=['variable'])
ivtable['IV']=None
namelist = ['Var_0', 'Var_1','Var_2','Var_3','Var_4','Var_5','Var_6','Var_7','Var_8','Var_9','Var_10','Var_11','Var_12',
           'Var_13','Var_14','Var_15', 'Var_1310','Var_10T', 'Var_13T']

for i in namelist:
    ivtable.drop(ivtable[ivtable['variable'] == i].index, inplace=True)

ivtable.head()
# Out:
#     variable    IV
# 16  Etiqueta  None
# 17  gp_Var_0  None
# 18  gp_Var_1  None
# 19  gp_Var_2  None
# 20  gp_Var_3  None

# %% [markdown]
# A continuación, revisamos las variables que desués de hacer una primera categorización, su WoE no era monotónico.  Estas variables son: Var_4, Var_5, Var_8 y Var_11 y les ponemos el prefijo gp2

# %%
namelist2= ['Var_4','Var_5','Var_8','Var_11']
for var in namelist2:
    print('Variable:',var)
    print('')
    df = get_category(df, var, 4, ["Muy Bajo", "Medio", "Alto","Muy alto"], 'gp2', qcut = True)
    iv, data = calc_iv(df,'gp2_'+var,'Etiqueta')
    ivtable.loc[ivtable['variable']== 'gp2_'+var,'IV']=iv
    print('')
    print(data)
    print('')
# Out:
# Variable: Var_4
#
# El IV de esta variable es: 0.8428038821070075
# Alto        2250
# Medio       2250
# Muy Bajo    2250
# Muy alto    2250
# Name: gp2_Var_4, dtype: int64
#
#     Variable     Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp2_Var_4      Alto  2250   971  1279   0.25  0.568444           0.215634
# 1  gp2_Var_4     Medio  2250  1528   722   0.25  0.320889           0.339329
# 2  gp2_Var_4  Muy Bajo  2250   399  1851   0.25  0.822667           0.088608
# 3  gp2_Var_4  Muy alto  2250  1605   645   0.25  0.286667           0.356429
#
#    Distribution Bad       WoE        IV
# 0          0.284412 -0.276841  0.019040
# 1          0.160551  0.748356  0.133790
# 2          0.411608 -1.535853  0.496081
# 3          0.143429  0.910295  0.193893
#
# Variable: Var_5
#
# El IV de esta variable es: 0.8428038821070075
# Alto        2250
# Medio       2250
# Muy Bajo    2250
# Muy alto    2250
# Name: gp2_Var_5, dtype: int64
#
#     Variable     Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp2_Var_5      Alto  2250   971  1279   0.25  0.568444           0.215634
# 1  gp2_Var_5     Medio  2250  1528   722   0.25  0.320889           0.339329
# 2  gp2_Var_5  Muy Bajo  2250   399  1851   0.25  0.822667           0.088608
# 3  gp2_Var_5  Muy alto  2250  1605   645   0.25  0.286667           0.356429
#
#    Distribution Bad       WoE        IV
# 0          0.284412 -0.276841  0.019040
# 1          0.160551  0.748356  0.133790
# 2          0.411608 -1.535853  0.496081
# 3          0.143429  0.910295  0.193893
#
# Variable: Var_8
#
# El IV de esta variable es: 0.4116751007354455
# Alto        2250
# Medio       2250
# Muy Bajo    2250
# Muy alto    2250
# Name: gp2_Var_8, dtype: int64
#
#     Variable     Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp2_Var_8      Alto  2250   689  1561   0.25  0.693778           0.153009
# 1  gp2_Var_8     Medio  2250  1046  1204   0.25  0.535111           0.232290
# 2  gp2_Var_8  Muy Bajo  2250  1662   588   0.25  0.261333           0.369087
# 3  gp2_Var_8  Muy alto  2250  1106  1144   0.25  0.508444           0.245614
#
#    Distribution Bad       WoE        IV
# 0          0.347120 -0.819174  0.159011
# 1          0.267734 -0.142009  0.005033
# 2          0.130754  1.037717  0.247323
# 3          0.254392 -0.035114  0.000308
#
# Variable: Var_11
#
# El IV de esta variable es: 0.8368463313381754
# Alto        2250
# Medio       2250
# Muy Bajo    2250
# Muy alto    2250
# Name: gp2_Var_11, dtype: int64
#
#      Variable     Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp2_Var_11      Alto  2250  1530   720   0.25  0.320000           0.339773
# 1  gp2_Var_11     Medio  2250   967  1283   0.25  0.570222           0.214746
# 2  gp2_Var_11  Muy Bajo  2250  1603   647   0.25  0.287556           0.355985
# 3  gp2_Var_11  Muy alto  2250   403  1847   0.25  0.820889           0.089496
#
#    Distribution Bad       WoE        IV
# 0          0.160107  0.752438  0.135188
# 1          0.285301 -0.284091  0.020044
# 2          0.143874  0.905953  0.192163
# 3          0.410718 -1.523715  0.489451

# %% [markdown]
# Al aumentar las categorías en todas las variables el WoE no es monotónico y el IV, excepto Var_8 aumento por encima de 0.5, por lo que ahora intentaremos disminuirlas. A las variables creada en este nuevo intento de categorización les poenemos el prefijo gp3.

# %%
namelist2= ['Var_4','Var_5','Var_8','Var_11']
for var in namelist2:
    print('Variable:',var)
    print('')
    df = get_category(df, var, 2, ["Bajo", "Alto"], 'gp3', qcut = True)
    iv, data = calc_iv(df,'gp3_'+var,'Etiqueta')
    ivtable.loc[ivtable['variable']== 'gp3_'+var,'IV']=iv
    print('')
    print(data)
    print('')
# Out:
# Variable: Var_4
#
# El IV de esta variable es: 0.08378443730708653
# Alto    4500
# Bajo    4500
# Name: gp3_Var_4, dtype: int64
#
#     Variable Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp3_Var_4  Alto  4500  2576  1924    0.5  0.427556           0.572063
# 1  gp3_Var_4  Bajo  4500  1927  2573    0.5  0.571778           0.427937
#
#    Distribution Bad       WoE        IV
# 0          0.427841  0.290498  0.041896
# 1          0.572159 -0.290441  0.041888
#
# Variable: Var_5
#
# El IV de esta variable es: 0.08378443730708653
# Alto    4500
# Bajo    4500
# Name: gp3_Var_5, dtype: int64
#
#     Variable Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp3_Var_5  Alto  4500  2576  1924    0.5  0.427556           0.572063
# 1  gp3_Var_5  Bajo  4500  1927  2573    0.5  0.571778           0.427937
#
#    Distribution Bad       WoE        IV
# 0          0.427841  0.290498  0.041896
# 1          0.572159 -0.290441  0.041888
#
# Variable: Var_8
#
# El IV de esta variable es: 0.1669725435147003
# Alto    4500
# Bajo    4500
# Name: gp3_Var_8, dtype: int64
#
#     Variable Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp3_Var_8  Alto  4500  1795  2705    0.5  0.601111           0.398623
# 1  gp3_Var_8  Bajo  4500  2708  1792    0.5  0.398222           0.601377
#
#    Distribution Bad       WoE        IV
# 0          0.601512 -0.411430  0.083475
# 1          0.398488  0.411545  0.083498
#
# Variable: Var_11
#
# El IV de esta variable es: 0.0806938649095072
# Alto    4500
# Bajo    4500
# Name: gp3_Var_11, dtype: int64
#
#      Variable Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp3_Var_11  Alto  4500  1933  2567    0.5  0.570444           0.429269
# 1  gp3_Var_11  Bajo  4500  2570  1930    0.5  0.428889           0.570731
#
#    Distribution Bad       WoE        IV
# 0          0.570825 -0.284998  0.040343
# 1          0.429175  0.285053  0.040351

# %% [markdown]
# En el resultado anterior vemos que todas las variables gp3_Var_4, gp3_Var_5, gp3_Var_8, gp3_Var_11 ahora tienen un WoE con tendencia monotónica y dos categorias. Su IV ya no es sospechoso. Sin embargo, gp4_Var_11 tiene muy poco poder predictivo pues su IV es menor a 0.1.

# %% [markdown]
# Revisamos nuevamente las variables con un IV sospechoso, mayor a 0.5 categorizandolas en dos grupos Alto y Bajo.  En este análisis creamos las variables con prefijo gp0.

# %%
namelist2= ['Var_0', 'Var_1', 'Var_2', 'Var_3', 'Var_6', 'Var_7', 'Var_12']
for var in namelist2:
    print('Variable:',var)
    print('')
    df = get_category(df, var, 2, ["Bajo", "Alto"], 'gp0', qcut = True)
    iv, data = calc_iv(df,'gp0_'+var,'Etiqueta')
    ivtable.loc[ivtable['variable']== 'gp0_'+var,'IV']=iv
    print('')
    print(data)
    print('')
# Out:
# Variable: Var_0
#
# El IV de esta variable es: 0.3529332280648383
# Alto    4500
# Bajo    4500
# Name: gp0_Var_0, dtype: int64
#
#     Variable Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp0_Var_0  Alto  4500  1593  2907    0.5  0.646000           0.353764
# 1  gp0_Var_0  Bajo  4500  2910  1590    0.5  0.353333           0.646236
#
#    Distribution Bad       WoE        IV
# 0          0.646431 -0.602836  0.176430
# 1          0.353569  0.603086  0.176503
#
# Variable: Var_1
#
# El IV de esta variable es: 0.3000240784483029
# Alto    4500
# Bajo    4500
# Name: gp0_Var_1, dtype: int64
#
#     Variable Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp0_Var_1  Alto  4500  1643  2857    0.5  0.634889           0.364868
# 1  gp0_Var_1  Bajo  4500  2860  1640    0.5  0.364444           0.635132
#
#    Distribution Bad       WoE        IV
# 0          0.635312 -0.554582  0.149984
# 1          0.364688  0.554792  0.150040
#
# Variable: Var_2
#
# El IV de esta variable es: 0.22488997734053415
# Alto    4500
# Bajo    4500
# Name: gp0_Var_2, dtype: int64
#
#     Variable Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp0_Var_2  Alto  4500  1723  2777    0.5  0.617111           0.382634
# 1  gp0_Var_2  Bajo  4500  2780  1720    0.5  0.382222           0.617366
#
#    Distribution Bad       WoE        IV
# 0          0.617523 -0.478638  0.112427
# 1          0.382477  0.478793  0.112463
#
# Variable: Var_3
#
# El IV de esta variable es: 2.290807898370839
# Alto    4500
# Bajo    4500
# Name: gp0_Var_3, dtype: int64
#
#     Variable Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp0_Var_3  Alto  4500   712  3788    0.5  0.841778           0.158117
# 1  gp0_Var_3  Bajo  4500  3791   709    0.5  0.157556           0.841883
#
#    Distribution Bad       WoE        IV
# 0          0.842339 -1.672849  1.144601
# 1          0.157661  1.675196  1.146207
#
# Variable: Var_6
#
# El IV de esta variable es: 0.35072700206824603
# Alto    4500
# Bajo    4500
# Name: gp0_Var_6, dtype: int64
#
#     Variable Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp0_Var_6  Alto  4500  1595  2905    0.5  0.645556           0.354208
# 1  gp0_Var_6  Bajo  4500  2908  1592    0.5  0.353778           0.645792
#
#    Distribution Bad       WoE        IV
# 0          0.645986 -0.600893  0.175327
# 1          0.354014  0.601141  0.175400
#
# Variable: Var_7
#
# El IV de esta variable es: 0.3529332280648383
# Alto    4500
# Bajo    4500
# Name: gp0_Var_7, dtype: int64
#
#     Variable Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp0_Var_7  Alto  4500  1593  2907    0.5  0.646000           0.353764
# 1  gp0_Var_7  Bajo  4500  2910  1590    0.5  0.353333           0.646236
#
#    Distribution Bad       WoE        IV
# 0          0.646431 -0.602836  0.176430
# 1          0.353569  0.603086  0.176503
#
# Variable: Var_12
#
# El IV de esta variable es: 2.434425702818398
# Alto    4500
# Bajo    4500
# Name: gp0_Var_12, dtype: int64
#
#      Variable Value   All  Good   Bad  Share  Bad Rate  Distribution Good  \
# 0  gp0_Var_12  Alto  4500  3828   672    0.5  0.149333             0.8501
# 1  gp0_Var_12  Bajo  4500   675  3825    0.5  0.850000             0.1499
#
#    Distribution Bad       WoE        IV
# 0          0.149433  1.738506  1.218114
# 1          0.850567 -1.735934  1.216312

# %% [markdown]
# Del resultado anterior se pude observar que al disminuir las categorías de las variables que tenían un IV mayor 1 obtenemos:
# - Var_0, Var_1, Var_2, Var_6, Var_7 ahora tienen un valor IV que indica un poder predictivo fuerte
# - Var_3 y Var_12 continuan con valores de IV que son sospechosos.

# %% [markdown]
# Ahora prepararemos los siguientes conjuntos de datos:
# - Todas las variables com IV medio a fuerte (0.1 a 0.5), gp_Var_9, gp_Var_14, gp_Var_15, gp3_Var_8, gp0_Var_0, gp0_Var_1, gp0_Var_2, gp0_Var_6, gp0_Var7, gpT_Var13 y gpT_Var_10
# - Todas las variables com IV medio a fuerte y la interacción (0.1 a 0.5), gp_Var_9, gp_Var_14, gp_Var_15, gp3_Var_8, gp0_Var_0, gp0_Var_1, gp0_Var_2, gp0_Var_6, gp0_Var7, gpT_Var13, gpT_Var_10 y gpI2_Var_1310
# - Sólo variables con IV fuerte (0.3 a 0.5), gp_Var_9, gp_Var_14, gp3_Var_0, gp3_Var_1, gp3_Var_6, gp3_Var7
# - Sólo variables con IV fuerte y la interacción (0.3 a 0.5), gp_Var_9, gp_Var_14, gp3_Var_0, gp3_Var_1, gp3_Var_6, gp3_Var7,  gpI2_Var_1310

# %% [markdown]
# Ahora creamos los dos dataframes

# %%
# Se crean las dummies de las variable
variable = ['gp0_Var_0','gp0_Var_1','gp0_Var_2','gp0_Var_6','gp0_Var_7', 'gp3_Var_8', 'gp_Var_9', 'gp_Var_14', 'gp_Var_15','gpI2_Var_1310',
            'gpT_Var_13T', 'gpT_Var_10T']

for var in variable:
    df= convert_dummy(df, var)
      
df
# Out:
#          Var_0     Var_1     Var_2     Var_3     Var_4     Var_5     Var_6  \
# 0    -0.549056 -0.774288 -0.962352 -0.070251 -1.463149 -1.856969 -0.555827
# 1     -0.62638 -0.707437 -0.710874 -0.662114  -0.29132  0.018311  -0.62559
# 2    -0.346858 -0.395211  -0.39333 -0.230728 -0.343911 -0.034514 -0.352208
# 3     0.468754  0.639619  0.702171  0.505147  0.373264  0.556315  0.489303
# 4     0.754127  1.098725  0.633525  1.154292 -0.449122 -0.145939  0.762335
# ...        ...       ...       ...       ...       ...       ...       ...
# 8995  0.093613  0.378953  0.780598 -0.405406   1.93732   1.27508  0.090056
# 8996  0.437172  0.831203  0.699108  0.410649  0.492297  0.632684  0.449248
# 8997 -0.626638 -0.833696 -0.910054  -0.41044 -0.991603 -0.877504  -0.63269
# 8998 -0.081528  0.100921  0.494164 -0.520546  1.656873  1.181195 -0.088059
# 8999 -0.527204 -0.658926 -0.619651 -0.481485 -0.388562 -0.080836 -0.532902
#
#          Var_7     Var_8     Var_9  ... gp_Var_14_Medio gp_Var_15_Bajo  \
# 0     -0.59745  0.358633  1.039852  ...               0              0
# 1    -0.708909 -0.595637 -0.088408  ...               1              0
# 2    -0.320637  0.637957  0.665042  ...               1              0
# 3     0.641623  0.301199 -1.873106  ...               0              1
# 4     0.936887 -0.579545 -0.788368  ...               0              0
# ...        ...       ...       ...  ...             ...            ...
# 8995  0.224398  -1.35441  0.251748  ...               0              0
# 8996  0.607859 -1.005722 -1.176671  ...               0              0
# 8997 -0.709287 -0.098565  1.012028  ...               0              0
# 8998  0.015889   0.98848  0.643806  ...               0              0
# 8999  -0.56655  1.321161  0.856331  ...               1              0
#
#      gp_Var_15_Medio gpI2_Var_1310_Bajo gpI2_Var_1310_Medio  \
# 0                  0                  0                   0
# 1                  1                  0                   1
# 2                  1                  0                   0
# 3                  0                  1                   0
# 4                  1                  0                   0
# ...              ...                ...                 ...
# 8995               1                  0                   0
# 8996               1                  0                   0
# 8997               0                  0                   0
# 8998               1                  1                   0
# 8999               0                  0                   0
#
#      gpI2_Var_1310_Muy bajo  gpT_Var_13T_Alto gpT_Var_13T_Medio  \
# 0                         0                 1                 0
# 1                         0                 1                 0
# 2                         0                 1                 0
# 3                         0                 0                 0
# 4                         1                 0                 0
# ...                     ...               ...               ...
# 8995                      1                 0                 1
# 8996                      1                 0                 0
# 8997                      0                 1                 0
# 8998                      0                 0                 1
# 8999                      0                 1                 0
#
#      gpT_Var_10T_Bajo gpT_Var_10T_Medio
# 0                   0                 0
# 1                   1                 0
# 2                   0                 1
# 3                   1                 0
# 4                   0                 0
# ...               ...               ...
# 8995                0                 0
# 8996                0                 0
# 8997                0                 0
# 8998                0                 1
# 8999                0                 1
#
# [9000 rows x 62 columns]

# %%
df.columns
# Out:
# Index(['Var_0', 'Var_1', 'Var_2', 'Var_3', 'Var_4', 'Var_5', 'Var_6', 'Var_7',
#        'Var_8', 'Var_9', 'Var_10', 'Var_11', 'Var_12', 'Var_13', 'Var_14',
#        'Var_15', 'Etiqueta', 'gp_Var_0', 'gp_Var_1', 'gp_Var_2', 'gp_Var_3',
#        'gp_Var_4', 'gp_Var_5', 'gp_Var_6', 'gp_Var_7', 'gp_Var_8', 'gp_Var_10',
#        'gp_Var_11', 'gp_Var_12', 'gp_Var_13', 'Var_1310', 'gpI1_Var_1310',
#        'Var_13T', 'Var_10T', 'gp2_Var_4', 'gp2_Var_5', 'gp2_Var_8',
#        'gp2_Var_11', 'gp3_Var_4', 'gp3_Var_5', 'gp3_Var_11', 'gp0_Var_3',
#        'gp0_Var_12', 'gp0_Var_0_Bajo', 'gp0_Var_1_Bajo', 'gp0_Var_2_Bajo',
#        'gp0_Var_6_Bajo', 'gp0_Var_7_Bajo', 'gp3_Var_8_Bajo', 'gp_Var_9_Bajo',
#        'gp_Var_9_Medio', 'gp_Var_14_Bajo', 'gp_Var_14_Medio', 'gp_Var_15_Bajo',
#        'gp_Var_15_Medio', 'gpI2_Var_1310_Bajo', 'gpI2_Var_1310_Medio',
#        'gpI2_Var_1310_Muy bajo', 'gpT_Var_13T_Alto', 'gpT_Var_13T_Medio',
#        'gpT_Var_10T_Bajo', 'gpT_Var_10T_Medio'],
#       dtype='object')

# %% [markdown]
# A pesar de que en el entrenamiento de los modelos utilizaremos validación cruzada, partiremos el conjunto de datos en entrenamiento prueba, esto con el fin de tener un conjunto de entrenamiento, uno de validación y uno de pruebas para cada modelo.
#
# Cuando se hace validación cruzada, el conjunto de entrenamiento es dividido en varias partes iguales, en nuestro caso 5. De estos subconjuntos 4 se utilizan para entrenamiento y 1 para validación y se reporta el resultado, luego se selecciona otro conjunto diferente para validación y con los cuatro restantes se entrena el mismo modelo y esto se repite 5 veces.  Al final de un mismo modelo se obtienen 5 métricas de precisión que son promediadas para cada obtener la metrica final del modelo.
#
# Al mismo tiempo se sintonizan los hiperparámetros de los modelos, para ello se escoge un cojunto de arquitecturas de red, funciones de activación y 10 valores de regularización entre 0 y 3.  Los modelos se van ajustando con las diferentes combinaciones de estos hiperparámetros con el fin de encontrar el mejor modelo, que es el que mayor accuracy tenga dado que la idea es encontrar un modelo que tenga la menor probabilida de error posible.
#
# La validación cruzada es útil en la detección de sobreajuste del modelo, y la regularización también ayuda a que el modelo generalice mejor, penalizando la complejidad ya que los modelos más complejos tienden a sobreajustarse, es decir que a pesar de tener muy buena metrica con los datos de entrenamiento, su desempeño decae enormemente cuando se prueban con otros cojuntos que provienen de la misma distribución que los datos de entrenamiento pero que el modelo no conoce.

# %%
#Vector de Etiqueta
df['Etiqueta']=Ydata[0]
Ydata = df['Etiqueta']

#Se separan los datos en entrenamiento y prueba.  Es importante aclarar que usaremos validación cruzada, así que los datos
#de prueba son para probar los mejores modelos que se obtengan de acuerdo de cada conjunto de variables seleccionadas.
df_train, df_test, y_train, y_test = train_test_split(df,Ydata, test_size=0.2, random_state = 10086)

# %%
# Se crean los conjuntos de datos de entrenamiento y prueba con las variables seleccionadas asi:
# XMFI conjunto de datos con las variables que tienen un poder predictivo IV Alto a fuerte y además hay al menos una variable 
#      de interacción
# XMF  conjunto de datos con las variables que tienen un poder predictivo IV Alto a fuerte sin interacciones
# XF   conjunto de datos con las variables que tienen un poder predictivo IV fuerte sin interacciones
# XFI  Conjunto de datos con las variables que tienen un poder predictivo IV fuerte y al menos una variable de interacción

# Conjunto de variables con poder predictivo mediano a fuerte e interacciones
XMFI_train = df_train[['gp0_Var_0_Bajo', 'gp0_Var_1_Bajo', 'gp0_Var_2_Bajo', 'gp0_Var_6_Bajo',
       'gp0_Var_7_Bajo', 'gp3_Var_8_Bajo', 'gp_Var_9_Bajo', 'gp_Var_9_Medio',
       'gp_Var_14_Medio', 'gp_Var_14_Bajo', 'gp_Var_15_Medio',
       'gp_Var_15_Bajo', 'gpI2_Var_1310_Bajo', 'gpI2_Var_1310_Muy bajo',
       'gpI2_Var_1310_Medio','gpT_Var_13T_Alto',
       'gpT_Var_13T_Medio', 'gpT_Var_10T_Medio', 'gpT_Var_10T_Bajo']]

XMFI_test = df_test[['gp0_Var_0_Bajo', 'gp0_Var_1_Bajo', 'gp0_Var_2_Bajo', 'gp0_Var_6_Bajo',
       'gp0_Var_7_Bajo', 'gp3_Var_8_Bajo', 'gp_Var_9_Bajo', 'gp_Var_9_Medio',
       'gp_Var_14_Medio', 'gp_Var_14_Bajo', 'gp_Var_15_Medio',
       'gp_Var_15_Bajo', 'gpI2_Var_1310_Bajo', 'gpI2_Var_1310_Muy bajo',
       'gpI2_Var_1310_Medio','gpT_Var_13T_Alto',
       'gpT_Var_13T_Medio', 'gpT_Var_10T_Medio', 'gpT_Var_10T_Bajo']]


## Conjunto de variables con poder predictivo mediano a fuerte
XMF_train = df_train[['gp0_Var_0_Bajo', 'gp0_Var_1_Bajo', 'gp0_Var_2_Bajo', 'gp0_Var_6_Bajo',
       'gp0_Var_7_Bajo', 'gp3_Var_8_Bajo', 'gp_Var_9_Bajo', 'gp_Var_9_Medio',
       'gp_Var_14_Medio', 'gp_Var_14_Bajo', 'gp_Var_15_Medio',
       'gp_Var_15_Bajo','gpT_Var_13T_Alto',
       'gpT_Var_13T_Medio', 'gpT_Var_10T_Medio', 'gpT_Var_10T_Bajo']]

XMF_test = df_test[['gp0_Var_0_Bajo', 'gp0_Var_1_Bajo', 'gp0_Var_2_Bajo', 'gp0_Var_6_Bajo',
       'gp0_Var_7_Bajo', 'gp3_Var_8_Bajo', 'gp_Var_9_Bajo', 'gp_Var_9_Medio',
       'gp_Var_14_Medio', 'gp_Var_14_Bajo', 'gp_Var_15_Medio',
       'gp_Var_15_Bajo', 'gpT_Var_13T_Alto',
       'gpT_Var_13T_Medio', 'gpT_Var_10T_Medio', 'gpT_Var_10T_Bajo']]


## Conjunto de variables con poder predictivo fuerte
#XF_train = df_train[['gp0_Var_0_Alto', 'gp0_Var_1_Alto', 'gp0_Var_6_Alto', 'gp0_Var_7_Alto',
 #      'gp_Var_9_Alto', 'gp_Var_9_Bajo', 'gp_Var_14_Alto', 'gp_Var_14_Bajo']]

#XF_test = df_test[['gp0_Var_0_Alto', 'gp0_Var_1_Alto', 'gp0_Var_6_Alto', 'gp0_Var_7_Alto',
#      'gp_Var_9_Alto', 'gp_Var_9_Bajo', 'gp_Var_14_Alto', 'gp_Var_14_Bajo']]

## Conjunto de variables con poder predictivo fuerte y al menos una interacción
#XFI_train = df_train[['gp0_Var_0_Alto', 'gp0_Var_1_Alto', 'gp0_Var_6_Alto', 'gp0_Var_7_Alto',
#      'gp_Var_9_Alto', 'gp_Var_9_Bajo', 'gp_Var_14_Alto', 'gp_Var_14_Bajo', 'gpI2_Var_1310_Alto', 'gpI2_Var_1310_Bajo','gpI2_Var_1310_Muy bajo']]

#XFI_test = df_test[['gp0_Var_0_Alto', 'gp0_Var_1_Alto', 'gp0_Var_6_Alto', 'gp0_Var_7_Alto',
#      'gp_Var_9_Alto', 'gp_Var_9_Bajo', 'gp_Var_14_Alto', 'gp_Var_14_Bajo', 'gpI2_Var_1310_Alto', 'gpI2_Var_1310_Bajo','gpI2_Var_1310_Muy bajo']]

# %%
#Con el fin de no generar cada vez que se corre el programa las dummies se guardan los dataframes en archivos
XMF_train.to_csv("XMF_train.csv")
XMF_test.to_csv("XMF_test.csv")
XMFI_train.to_csv("XMFI_train.csv")
XMFI_test.to_csv("XMFI_test.csv")

# %% [markdown]
# Se utilizaran 2 conjuntos diferentes de variables descriptoras para ajustar varios modelos donde se varía su arquitectura, función de activación y la regularización.

# %%
#********  EN CASO DE QUERER CORRER LOS MODELOS Y NO HAYAN CAMBIADO LAS VARIABLES CORRRE ESTA CODÍGO PARA CARGAR *********
#********  LOS DATAFRAMES YA CON LAS VARIABLES DUMMIES. ******************************************************************

#Se cargan los  dataframes de entrenamiento y prueba para los modelos.
XMF_train = pd.read_csv("XMF_train.csv")
XMF_test = pd.read_csv("XMF_test.csv")
XMFI_train = pd.read_csv("XMFI_train.csv")
XMFI_test = pd.read_csv("XMFI_test.csv")

# %% [markdown]
# ## Modelos ajustados con variables con poder predictivo medio a fuerte y sin interacciones.

# %%
#Se crea un vector con las arquitecturas de red a probar.
Estructura=[(5,5), (5,5,5),(10,10),(10,10,10),(20,20),(20,20,20),(50,50),(50,50,50),(100,100),(100,100,100),(50,10,100)]
Activacion = ['relu','logistic']  #Funciones de activación para probar
alfa = np.linspace(0,3,num=10) #Se generan 10 valores de regularizacion entre 0 y 3.


#Se incializan variables para saber cual es el mejor modelo creado.
accs_opt1 = 0
cont_m1 = None
hidden_layers_opt1 = None
acts_opt1 = None
regs_opt1 = None
# Se crean listas de las métricas de evaluación a graficar.
# crear lista de metricas de evaluacion a graficar
acc_list1 = []
prec_list1 = []
rec_list1 = []
bal_acc_list1 = []
f1_list1 = []
contador1 = []
cont1 = 1 # Contador que nos servira como id del modelo ajustado.
for reg in alfa:
    for est in Estructura:
        for act in Activacion:
            ModeloMF = MLPClassifier(hidden_layer_sizes = est, activation=act, alpha=reg)
            res_acc = cross_val_score(ModeloMF,XMF_train, y_train, scoring='accuracy',n_jobs=-1)
            avg_acc = np.mean(res_acc)
            res_prec = cross_val_score(ModeloMF,XMF_train, y_train, scoring='precision',n_jobs=-1)
            avg_prec = round(np.mean(res_prec),4)
            res_rec = cross_val_score(ModeloMF,XMF_train, y_train, scoring='recall',n_jobs=-1)
            avg_rec = round(np.mean(res_rec),4)
            res_bal = cross_val_score(ModeloMF,XMF_train, y_train, scoring='balanced_accuracy',n_jobs=-1)
            avg_bal = round(np.mean(res_bal),4)
            res_f1 = cross_val_score(ModeloMF,XMF_train, y_train, scoring='f1',n_jobs=-1)
            avg_f1 = round(np.mean(res_f1),4)
            
            #Agregamos métricas de evaluación a la listas
            acc_list1.append(avg_acc)
            prec_list1.append(avg_prec)
            rec_list1.append(avg_rec)
            bal_acc_list1.append(avg_bal)
            f1_list1.append(avg_f1)
            contador1.append(cont1)
            
            
            print('Las métricas de evaluación del modelo '+ str(cont1)+' con estructura  [' +str(est)+ '] función de activación ' +str(act) + ' y regularización L2 ' + str(reg)+ ' son:'  )
            print('Accuracy: ' + str(avg_acc))
            print('Precision: ' + str(avg_prec))
            print('Recall: ' + str(avg_rec))
            print('Balance accuracy: ' + str(avg_bal))
            print('F1: ' + str(avg_f1))
            print(' ')
          
            
            #Dado que se evaluará la probabilidad de error del modelo, se escoge el mejor modelo con base en el Accuracy
            if avg_acc > accs_opt1:
                accs_opt1 = avg_acc
                hidden_layers_opt1 = est
                acts_opt1 = act
                regs_opt1 = reg
                cont_m1 = cont1
                  
            cont1 +=1
# Out:
# Las métricas de evaluación del modelo 1 con estructura  [(5, 5)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.882638888888889
# Precision: 0.8784
# Recall: 0.8971
# Balance accuracy: 0.8821
# F1: 0.8888
#
# Las métricas de evaluación del modelo 2 con estructura  [(5, 5)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.877361111111111
# Precision: 0.8711
# Recall: 0.9009
# Balance accuracy: 0.8787
# F1: 0.8824
#
# Las métricas de evaluación del modelo 3 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8816666666666666
# Precision: 0.8772
# Recall: 0.893
# Balance accuracy: 0.8799
# F1: 0.8827
#
# Las métricas de evaluación del modelo 4 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8502777777777778
# Precision: 0.8725
# Recall: 0.896
# Balance accuracy: 0.8505
# F1: 0.8004
#
# Las métricas de evaluación del modelo 5 con estructura  [(10, 10)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8863888888888889
# Precision: 0.8809
# Recall: 0.9006
# Balance accuracy: 0.8844
# F1: 0.8884
#
# Las métricas de evaluación del modelo 6 con estructura  [(10, 10)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8793055555555556
# Precision: 0.8676
# Recall: 0.9014
# Balance accuracy: 0.8798
# F1: 0.8816
#
# Las métricas de evaluación del modelo 7 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8873611111111112
# Precision: 0.8784
# Recall: 0.8897
# Balance accuracy: 0.8838
# F1: 0.8838
#
# Las métricas de evaluación del modelo 8 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8229166666666666
# Precision: 0.8781
# Recall: 0.8336
# Balance accuracy: 0.8835
# F1: 0.8847
#
# Las métricas de evaluación del modelo 9 con estructura  [(20, 20)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8854166666666666
# Precision: 0.8826
# Recall: 0.8965
# Balance accuracy: 0.8849
# F1: 0.8904
#
# Las métricas de evaluación del modelo 10 con estructura  [(20, 20)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8819444444444443
# Precision: 0.8693
# Recall: 0.9039
# Balance accuracy: 0.881
# F1: 0.8854
#
# Las métricas de evaluación del modelo 11 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8893055555555556
# Precision: 0.8782
# Recall: 0.9015
# Balance accuracy: 0.885
# F1: 0.8829
#
# Las métricas de evaluación del modelo 12 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8838888888888888
# Precision: 0.8724
# Recall: 0.8971
# Balance accuracy: 0.8825
# F1: 0.8842
#
# Las métricas de evaluación del modelo 13 con estructura  [(50, 50)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8851388888888888
# Precision: 0.8914
# Recall: 0.8935
# Balance accuracy: 0.8848
# F1: 0.8868
#
# Las métricas de evaluación del modelo 14 con estructura  [(50, 50)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8793055555555556
# Precision: 0.8744
# Recall: 0.9015
# Balance accuracy: 0.8829
# F1: 0.8864
#
# Las métricas de evaluación del modelo 15 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8843055555555555
# Precision: 0.8809
# Recall: 0.8878
# Balance accuracy: 0.8827
# F1: 0.886
#
# Las métricas de evaluación del modelo 16 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.88375
# Precision: 0.8835
# Recall: 0.8965
# Balance accuracy: 0.881
# F1: 0.8861
#
# Las métricas de evaluación del modelo 17 con estructura  [(100, 100)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8861111111111111
# Precision: 0.8867
# Recall: 0.891
# Balance accuracy: 0.8847
# F1: 0.8872
#
# Las métricas de evaluación del modelo 18 con estructura  [(100, 100)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8820833333333333
# Precision: 0.8722
# Recall: 0.8965
# Balance accuracy: 0.8811
# F1: 0.8853
#
# Las métricas de evaluación del modelo 19 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8798611111111111
# Precision: 0.869
# Recall: 0.8732
# Balance accuracy: 0.8841
# F1: 0.8849
#
# Las métricas de evaluación del modelo 20 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8777777777777777
# Precision: 0.8776
# Recall: 0.8943
# Balance accuracy: 0.8822
# F1: 0.8856
#
# Las métricas de evaluación del modelo 21 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8865277777777777
# Precision: 0.8803
# Recall: 0.8894
# Balance accuracy: 0.8869
# F1: 0.8873
#
# Las métricas de evaluación del modelo 22 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8818055555555555
# Precision: 0.8763
# Recall: 0.8919
# Balance accuracy: 0.8815
# F1: 0.8851
#
# Las métricas de evaluación del modelo 23 con estructura  [(5, 5)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8781944444444445
# Precision: 0.8741
# Recall: 0.896
# Balance accuracy: 0.8807
# F1: 0.8843
#
# Las métricas de evaluación del modelo 24 con estructura  [(5, 5)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8444444444444444
# Precision: 0.8273
# Recall: 0.8842
# Balance accuracy: 0.8586
# F1: 0.8666
#
# Las métricas de evaluación del modelo 25 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8841666666666667
# Precision: 0.8699
# Recall: 0.8845
# Balance accuracy: 0.8822
# F1: 0.8838
#
# Las métricas de evaluación del modelo 26 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 27 con estructura  [(10, 10)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8859722222222223
# Precision: 0.879
# Recall: 0.9014
# Balance accuracy: 0.8827
# F1: 0.8866
#
# Las métricas de evaluación del modelo 28 con estructura  [(10, 10)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8701388888888889
# Precision: 0.8503
# Recall: 0.8952
# Balance accuracy: 0.85
# F1: 0.8699
#
# Las métricas de evaluación del modelo 29 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8856944444444445
# Precision: 0.882
# Recall: 0.891
# Balance accuracy: 0.8816
# F1: 0.8881
#
# Las métricas de evaluación del modelo 30 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.7083
#
# Las métricas de evaluación del modelo 31 con estructura  [(20, 20)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8855555555555554
# Precision: 0.8803
# Recall: 0.8951
# Balance accuracy: 0.8846
# F1: 0.8868
#
# Las métricas de evaluación del modelo 32 con estructura  [(20, 20)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8572222222222223
# Precision: 0.8552
# Recall: 0.8932
# Balance accuracy: 0.8534
# F1: 0.8742
#
# Las métricas de evaluación del modelo 33 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8852777777777778
# Precision: 0.8787
# Recall: 0.8891
# Balance accuracy: 0.8845
# F1: 0.8888
#
# Las métricas de evaluación del modelo 34 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 35 con estructura  [(50, 50)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8881944444444445
# Precision: 0.8737
# Recall: 0.9047
# Balance accuracy: 0.8867
# F1: 0.8878
#
# Las métricas de evaluación del modelo 36 con estructura  [(50, 50)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8459722222222222
# Precision: 0.8392
# Recall: 0.8724
# Balance accuracy: 0.8394
# F1: 0.8459
# Las métricas de evaluación del modelo 37 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8831944444444444
# Precision: 0.8809
# Recall: 0.8979
# Balance accuracy: 0.8849
# F1: 0.8845
#
# Las métricas de evaluación del modelo 38 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.49874999999999997
# Precision: 0.3043
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 39 con estructura  [(100, 100)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8859722222222223
# Precision: 0.8879
# Recall: 0.8908
# Balance accuracy: 0.8847
# F1: 0.8871
#
# Las métricas de evaluación del modelo 40 con estructura  [(100, 100)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8358333333333332
# Precision: 0.8338
# Recall: 0.8686
# Balance accuracy: 0.8327
# F1: 0.834
#
# Las métricas de evaluación del modelo 41 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8843055555555555
# Precision: 0.8869
# Recall: 0.8889
# Balance accuracy: 0.8849
# F1: 0.8844
#
# Las métricas de evaluación del modelo 42 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.49847222222222226
# Precision: 0.3043
# Recall: 0.8
# Balance accuracy: 0.57
# F1: 0.4039
#
# Las métricas de evaluación del modelo 43 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8847222222222222
# Precision: 0.8814
# Recall: 0.9064
# Balance accuracy: 0.8854
# F1: 0.8898
#
# Las métricas de evaluación del modelo 44 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.5015277777777778
# Precision: 0.4058
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 45 con estructura  [(5, 5)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8802777777777777
# Precision: 0.867
# Recall: 0.9023
# Balance accuracy: 0.8824
# F1: 0.8846
#
# Las métricas de evaluación del modelo 46 con estructura  [(5, 5)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8254166666666667
# Precision: 0.8071
# Recall: 0.856
# Balance accuracy: 0.8232
# F1: 0.828
#
# Las métricas de evaluación del modelo 47 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8805555555555555
# Precision: 0.8775
# Recall: 0.8952
# Balance accuracy: 0.8814
# F1: 0.8836
#
# Las métricas de evaluación del modelo 48 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 49 con estructura  [(10, 10)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8822222222222221
# Precision: 0.8809
# Recall: 0.8976
# Balance accuracy: 0.8843
# F1: 0.8862
#
# Las métricas de evaluación del modelo 50 con estructura  [(10, 10)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.820138888888889
# Precision: 0.805
# Recall: 0.8533
# Balance accuracy: 0.8181
# F1: 0.8326
#
# Las métricas de evaluación del modelo 51 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8831944444444444
# Precision: 0.8834
# Recall: 0.8927
# Balance accuracy: 0.8833
# F1: 0.887
#
# Las métricas de evaluación del modelo 52 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 53 con estructura  [(20, 20)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8863888888888889
# Precision: 0.8749
# Recall: 0.8987
# Balance accuracy: 0.8853
# F1: 0.8866
#
# Las métricas de evaluación del modelo 54 con estructura  [(20, 20)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8216666666666667
# Precision: 0.8078
# Recall: 0.8497
# Balance accuracy: 0.8224
# F1: 0.8283
#
# Las métricas de evaluación del modelo 55 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.883611111111111
# Precision: 0.8912
# Recall: 0.8916
# Balance accuracy: 0.8853
# F1: 0.8881
#
# Las métricas de evaluación del modelo 56 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.5045833333333333
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 57 con estructura  [(50, 50)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8862500000000001
# Precision: 0.8902
# Recall: 0.8869
# Balance accuracy: 0.8846
# F1: 0.8874
#
# Las métricas de evaluación del modelo 58 con estructura  [(50, 50)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8265277777777778
# Precision: 0.806
# Recall: 0.859
# Balance accuracy: 0.8222
# F1: 0.8326
#
# Las métricas de evaluación del modelo 59 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8869444444444445
# Precision: 0.8833
# Recall: 0.8839
# Balance accuracy: 0.8864
# F1: 0.8892
#
# Las métricas de evaluación del modelo 60 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.49847222222222226
# Precision: 0.406
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 61 con estructura  [(100, 100)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8863888888888889
# Precision: 0.8834
# Recall: 0.8968
# Balance accuracy: 0.8847
# F1: 0.8866
#
# Las métricas de evaluación del modelo 62 con estructura  [(100, 100)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8252777777777778
# Precision: 0.7944
# Recall: 0.8533
# Balance accuracy: 0.8228
# F1: 0.8314
#
# Las métricas de evaluación del modelo 63 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8875
# Precision: 0.8636
# Recall: 0.8908
# Balance accuracy: 0.8866
# F1: 0.887
#
# Las métricas de evaluación del modelo 64 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.5043055555555556
# Precision: 0.4058
# Recall: 0.4
# Balance accuracy: 0.5
# F1: 0.2692
#
# Las métricas de evaluación del modelo 65 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8858333333333335
# Precision: 0.8928
# Recall: 0.8891
# Balance accuracy: 0.8852
# F1: 0.8881
#
# Las métricas de evaluación del modelo 66 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.5043055555555556
# Precision: 0.3044
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 67 con estructura  [(5, 5)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8791666666666667
# Precision: 0.8753
# Recall: 0.8875
# Balance accuracy: 0.8817
# F1: 0.8863
#
# Las métricas de evaluación del modelo 68 con estructura  [(5, 5)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.7551388888888889
# Precision: 0.6851
# Recall: 0.8516
# Balance accuracy: 0.7144
# F1: 0.766
#
# Las métricas de evaluación del modelo 69 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.883472222222222
# Precision: 0.873
# Recall: 0.8938
# Balance accuracy: 0.8801
# F1: 0.8824
#
# Las métricas de evaluación del modelo 70 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 71 con estructura  [(10, 10)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8815277777777778
# Precision: 0.8774
# Recall: 0.8965
# Balance accuracy: 0.8831
# F1: 0.8858
# Las métricas de evaluación del modelo 72 con estructura  [(10, 10)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.8190277777777777
# Precision: 0.8005
# Recall: 0.856
# Balance accuracy: 0.8174
# F1: 0.8254
#
# Las métricas de evaluación del modelo 73 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8844444444444445
# Precision: 0.8703
# Recall: 0.899
# Balance accuracy: 0.8846
# F1: 0.8849
#
# Las métricas de evaluación del modelo 74 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 75 con estructura  [(20, 20)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8833333333333332
# Precision: 0.8798
# Recall: 0.8968
# Balance accuracy: 0.8838
# F1: 0.8865
#
# Las métricas de evaluación del modelo 76 con estructura  [(20, 20)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.8191666666666666
# Precision: 0.807
# Recall: 0.8538
# Balance accuracy: 0.8205
# F1: 0.8326
#
# Las métricas de evaluación del modelo 77 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.884861111111111
# Precision: 0.8812
# Recall: 0.8976
# Balance accuracy: 0.8842
# F1: 0.8874
#
# Las métricas de evaluación del modelo 78 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 79 con estructura  [(50, 50)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8872222222222221
# Precision: 0.8601
# Recall: 0.905
# Balance accuracy: 0.8853
# F1: 0.8888
#
# Las métricas de evaluación del modelo 80 con estructura  [(50, 50)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.8183333333333334
# Precision: 0.803
# Recall: 0.847
# Balance accuracy: 0.8212
# F1: 0.8248
#
# Las métricas de evaluación del modelo 81 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8877777777777777
# Precision: 0.8916
# Recall: 0.8973
# Balance accuracy: 0.8848
# F1: 0.8875
#
# Las métricas de evaluación del modelo 82 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.5045833333333333
# Precision: 0.2029
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.2692
#
# Las métricas de evaluación del modelo 83 con estructura  [(100, 100)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8868055555555555
# Precision: 0.8882
# Recall: 0.8869
# Balance accuracy: 0.8834
# F1: 0.8877
#
# Las métricas de evaluación del modelo 84 con estructura  [(100, 100)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.8216666666666667
# Precision: 0.8071
# Recall: 0.8311
# Balance accuracy: 0.8196
# F1: 0.8293
#
# Las métricas de evaluación del modelo 85 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8875
# Precision: 0.8846
# Recall: 0.8968
# Balance accuracy: 0.8871
# F1: 0.887
#
# Las métricas de evaluación del modelo 86 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.49847222222222226
# Precision: 0.406
# Recall: 0.2
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 87 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8865277777777777
# Precision: 0.8741
# Recall: 0.9034
# Balance accuracy: 0.887
# F1: 0.8879
#
# Las métricas de evaluación del modelo 88 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.5043055555555556
# Precision: 0.3044
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 89 con estructura  [(5, 5)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8763888888888889
# Precision: 0.8673
# Recall: 0.896
# Balance accuracy: 0.8764
# F1: 0.8796
#
# Las métricas de evaluación del modelo 90 con estructura  [(5, 5)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.635
# Precision: 0.6274
# Recall: 0.9751
# Balance accuracy: 0.6283
# F1: 0.7655
#
# Las métricas de evaluación del modelo 91 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.881111111111111
# Precision: 0.875
# Recall: 0.8941
# Balance accuracy: 0.8812
# F1: 0.8816
#
# Las métricas de evaluación del modelo 92 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 93 con estructura  [(10, 10)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8809722222222222
# Precision: 0.8755
# Recall: 0.8982
# Balance accuracy: 0.8803
# F1: 0.8843
#
# Las métricas de evaluación del modelo 94 con estructura  [(10, 10)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.6984722222222222
# Precision: 0.7606
# Recall: 0.8587
# Balance accuracy: 0.7885
# F1: 0.7864
#
# Las métricas de evaluación del modelo 95 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8822222222222221
# Precision: 0.8792
# Recall: 0.9086
# Balance accuracy: 0.8834
# F1: 0.8892
#
# Las métricas de evaluación del modelo 96 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 97 con estructura  [(20, 20)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8848611111111111
# Precision: 0.8742
# Recall: 0.8875
# Balance accuracy: 0.8826
# F1: 0.8877
#
# Las métricas de evaluación del modelo 98 con estructura  [(20, 20)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.7509722222222223
# Precision: 0.8038
# Recall: 0.8396
# Balance accuracy: 0.7788
# F1: 0.8288
#
# Las métricas de evaluación del modelo 99 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8830555555555556
# Precision: 0.8779
# Recall: 0.8971
# Balance accuracy: 0.8845
# F1: 0.8846
#
# Las métricas de evaluación del modelo 100 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 101 con estructura  [(50, 50)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8847222222222223
# Precision: 0.8789
# Recall: 0.8979
# Balance accuracy: 0.8842
# F1: 0.8874
#
# Las métricas de evaluación del modelo 102 con estructura  [(50, 50)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8193055555555555
# Precision: 0.7963
# Recall: 0.8776
# Balance accuracy: 0.8205
# F1: 0.8247
#
# Las métricas de evaluación del modelo 103 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8856944444444445
# Precision: 0.8947
# Recall: 0.9006
# Balance accuracy: 0.8851
# F1: 0.888
#
# Las métricas de evaluación del modelo 104 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.5045833333333333
# Precision: 0.5074
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 105 con estructura  [(100, 100)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8836111111111112
# Precision: 0.8817
# Recall: 0.9108
# Balance accuracy: 0.8837
# F1: 0.8834
#
# Las métricas de evaluación del modelo 106 con estructura  [(100, 100)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8140277777777778
# Precision: 0.8019
# Recall: 0.8448
# Balance accuracy: 0.8121
# F1: 0.828
#
# Las métricas de evaluación del modelo 107 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8858333333333333
# Precision: 0.8858
# Recall: 0.9009
# Balance accuracy: 0.8843
# F1: 0.8893
# Las métricas de evaluación del modelo 108 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.49847222222222226
# Precision: 0.3044
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.5386
#
# Las métricas de evaluación del modelo 109 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8851388888888888
# Precision: 0.8833
# Recall: 0.8905
# Balance accuracy: 0.8848
# F1: 0.8877
#
# Las métricas de evaluación del modelo 110 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.5045833333333333
# Precision: 0.5074
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.0
#
# Las métricas de evaluación del modelo 111 con estructura  [(5, 5)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8766666666666666
# Precision: 0.868
# Recall: 0.9012
# Balance accuracy: 0.8736
# F1: 0.8764
#
# Las métricas de evaluación del modelo 112 con estructura  [(5, 5)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.5709722222222221
# Precision: 0.5232
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.7042
#
# Las métricas de evaluación del modelo 113 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8825
# Precision: 0.8703
# Recall: 0.8979
# Balance accuracy: 0.8785
# F1: 0.8812
#
# Las métricas de evaluación del modelo 114 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 115 con estructura  [(10, 10)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8786111111111111
# Precision: 0.8727
# Recall: 0.8962
# Balance accuracy: 0.8808
# F1: 0.8821
#
# Las métricas de evaluación del modelo 116 con estructura  [(10, 10)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.5411111111111111
# Precision: 0.5815
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6907
#
# Las métricas de evaluación del modelo 117 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8815277777777778
# Precision: 0.8753
# Recall: 0.8946
# Balance accuracy: 0.8817
# F1: 0.8859
#
# Las métricas de evaluación del modelo 118 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 119 con estructura  [(20, 20)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8802777777777777
# Precision: 0.8742
# Recall: 0.8998
# Balance accuracy: 0.882
# F1: 0.8846
#
# Las métricas de evaluación del modelo 120 con estructura  [(20, 20)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.6026388888888888
# Precision: 0.532
# Recall: 0.905
# Balance accuracy: 0.6548
# F1: 0.6732
#
# Las métricas de evaluación del modelo 121 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.88375
# Precision: 0.8796
# Recall: 0.8987
# Balance accuracy: 0.883
# F1: 0.8893
#
# Las métricas de evaluación del modelo 122 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 123 con estructura  [(50, 50)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8827777777777778
# Precision: 0.8682
# Recall: 0.8987
# Balance accuracy: 0.8823
# F1: 0.8857
#
# Las métricas de evaluación del modelo 124 con estructura  [(50, 50)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.6772222222222222
# Precision: 0.6926
# Recall: 0.8892
# Balance accuracy: 0.7536
# F1: 0.7337
#
# Las métricas de evaluación del modelo 125 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.885
# Precision: 0.8704
# Recall: 0.896
# Balance accuracy: 0.8826
# F1: 0.8862
#
# Las métricas de evaluación del modelo 126 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.5015277777777778
# Precision: 0.406
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 127 con estructura  [(100, 100)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8818055555555556
# Precision: 0.8759
# Recall: 0.9053
# Balance accuracy: 0.8804
# F1: 0.8889
#
# Las métricas de evaluación del modelo 128 con estructura  [(100, 100)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8109722222222222
# Precision: 0.7612
# Recall: 0.7452
# Balance accuracy: 0.8085
# F1: 0.7624
#
# Las métricas de evaluación del modelo 129 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8859722222222223
# Precision: 0.8813
# Recall: 0.8831
# Balance accuracy: 0.8874
# F1: 0.8865
#
# Las métricas de evaluación del modelo 130 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.4954166666666667
# Precision: 0.5074
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 131 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8877777777777778
# Precision: 0.8842
# Recall: 0.8935
# Balance accuracy: 0.8849
# F1: 0.887
#
# Las métricas de evaluación del modelo 132 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.4058
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.5386
#
# Las métricas de evaluación del modelo 133 con estructura  [(5, 5)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8752777777777778
# Precision: 0.8684
# Recall: 0.919
# Balance accuracy: 0.8749
# F1: 0.8802
#
# Las métricas de evaluación del modelo 134 con estructura  [(5, 5)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 135 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8773611111111113
# Precision: 0.792
# Recall: 0.896
# Balance accuracy: 0.8737
# F1: 0.8425
#
# Las métricas de evaluación del modelo 136 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 137 con estructura  [(10, 10)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8779166666666667
# Precision: 0.8739
# Recall: 0.893
# Balance accuracy: 0.8757
# F1: 0.8829
#
# Las métricas de evaluación del modelo 138 con estructura  [(10, 10)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 139 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8844444444444444
# Precision: 0.8763
# Recall: 0.9157
# Balance accuracy: 0.881
# F1: 0.8828
#
# Las métricas de evaluación del modelo 140 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 141 con estructura  [(20, 20)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8808333333333334
# Precision: 0.8655
# Recall: 0.8976
# Balance accuracy: 0.8804
# F1: 0.8856
#
# Las métricas de evaluación del modelo 142 con estructura  [(20, 20)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
# Las métricas de evaluación del modelo 143 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8838888888888888
# Precision: 0.8756
# Recall: 0.8973
# Balance accuracy: 0.8832
# F1: 0.8852
#
# Las métricas de evaluación del modelo 144 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 145 con estructura  [(50, 50)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8798611111111111
# Precision: 0.8805
# Recall: 0.8858
# Balance accuracy: 0.8806
# F1: 0.8826
#
# Las métricas de evaluación del modelo 146 con estructura  [(50, 50)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.5043055555555556
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 147 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8850000000000001
# Precision: 0.8707
# Recall: 0.8834
# Balance accuracy: 0.8841
# F1: 0.887
#
# Las métricas de evaluación del modelo 148 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.4041
#
# Las métricas de evaluación del modelo 149 con estructura  [(100, 100)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8802777777777779
# Precision: 0.8771
# Recall: 0.8941
# Balance accuracy: 0.8811
# F1: 0.8839
#
# Las métricas de evaluación del modelo 150 con estructura  [(100, 100)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.5043055555555556
# Precision: 0.3043
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.4038
#
# Las métricas de evaluación del modelo 151 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8875
# Precision: 0.8662
# Recall: 0.9003
# Balance accuracy: 0.8848
# F1: 0.8858
#
# Las métricas de evaluación del modelo 152 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.3044
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 153 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8859722222222223
# Precision: 0.8754
# Recall: 0.8954
# Balance accuracy: 0.8817
# F1: 0.889
#
# Las métricas de evaluación del modelo 154 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.49847222222222226
# Precision: 0.3044
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 155 con estructura  [(5, 5)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8693055555555557
# Precision: 0.8634
# Recall: 0.8908
# Balance accuracy: 0.8731
# F1: 0.8812
#
# Las métricas de evaluación del modelo 156 con estructura  [(5, 5)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 157 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8788888888888888
# Precision: 0.8681
# Recall: 0.8951
# Balance accuracy: 0.8754
# F1: 0.8806
#
# Las métricas de evaluación del modelo 158 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 159 con estructura  [(10, 10)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8777777777777777
# Precision: 0.869
# Recall: 0.893
# Balance accuracy: 0.8755
# F1: 0.8814
#
# Las métricas de evaluación del modelo 160 con estructura  [(10, 10)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 161 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8784722222222221
# Precision: 0.8755
# Recall: 0.8982
# Balance accuracy: 0.8786
# F1: 0.8805
#
# Las métricas de evaluación del modelo 162 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 163 con estructura  [(20, 20)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8797222222222223
# Precision: 0.8741
# Recall: 0.8946
# Balance accuracy: 0.879
# F1: 0.881
#
# Las métricas de evaluación del modelo 164 con estructura  [(20, 20)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 165 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.882638888888889
# Precision: 0.8751
# Recall: 0.9006
# Balance accuracy: 0.8837
# F1: 0.8875
#
# Las métricas de evaluación del modelo 166 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 167 con estructura  [(50, 50)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8791666666666667
# Precision: 0.8754
# Recall: 0.9001
# Balance accuracy: 0.8773
# F1: 0.8836
#
# Las métricas de evaluación del modelo 168 con estructura  [(50, 50)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.4058
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 169 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8850000000000001
# Precision: 0.8812
# Recall: 0.8982
# Balance accuracy: 0.8808
# F1: 0.885
#
# Las métricas de evaluación del modelo 170 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.50125
# Precision: 0.406
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.5386
#
# Las métricas de evaluación del modelo 171 con estructura  [(100, 100)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8800000000000001
# Precision: 0.8704
# Recall: 0.8982
# Balance accuracy: 0.8771
# F1: 0.8827
#
# Las métricas de evaluación del modelo 172 con estructura  [(100, 100)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.49847222222222226
# Precision: 0.406
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.2691
#
# Las métricas de evaluación del modelo 173 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8830555555555556
# Precision: 0.8637
# Recall: 0.9146
# Balance accuracy: 0.8802
# F1: 0.8887
#
# Las métricas de evaluación del modelo 174 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.5015277777777778
# Precision: 0.4058
# Recall: 0.4
# Balance accuracy: 0.5
# F1: 0.4038
#
# Las métricas de evaluación del modelo 175 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.881388888888889
# Precision: 0.8727
# Recall: 0.9025
# Balance accuracy: 0.8828
# F1: 0.891
#
# Las métricas de evaluación del modelo 176 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.5015277777777778
# Precision: 0.4058
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 177 con estructura  [(5, 5)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8740277777777778
# Precision: 0.8603
# Recall: 0.8946
# Balance accuracy: 0.8751
# F1: 0.8789
# Las métricas de evaluación del modelo 178 con estructura  [(5, 5)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 179 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8780555555555555
# Precision: 0.7947
# Recall: 0.8957
# Balance accuracy: 0.8782
# F1: 0.8817
#
# Las métricas de evaluación del modelo 180 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 181 con estructura  [(10, 10)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8754166666666666
# Precision: 0.8679
# Recall: 0.8946
# Balance accuracy: 0.8732
# F1: 0.8807
#
# Las métricas de evaluación del modelo 182 con estructura  [(10, 10)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 183 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8787499999999999
# Precision: 0.8677
# Recall: 0.8935
# Balance accuracy: 0.8826
# F1: 0.8843
#
# Las métricas de evaluación del modelo 184 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 185 con estructura  [(20, 20)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8775000000000001
# Precision: 0.8663
# Recall: 0.9012
# Balance accuracy: 0.8789
# F1: 0.883
#
# Las métricas de evaluación del modelo 186 con estructura  [(20, 20)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 187 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8823611111111112
# Precision: 0.8715
# Recall: 0.8965
# Balance accuracy: 0.884
# F1: 0.8871
#
# Las métricas de evaluación del modelo 188 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 189 con estructura  [(50, 50)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8788888888888889
# Precision: 0.8654
# Recall: 0.8954
# Balance accuracy: 0.8777
# F1: 0.8806
#
# Las métricas de evaluación del modelo 190 con estructura  [(50, 50)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.5045833333333333
# Precision: 0.406
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 191 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8820833333333333
# Precision: 0.8652
# Recall: 0.9023
# Balance accuracy: 0.8822
# F1: 0.8858
#
# Las métricas de evaluación del modelo 192 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.5015277777777778
# Precision: 0.5074
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 193 con estructura  [(100, 100)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8790277777777777
# Precision: 0.8619
# Recall: 0.9004
# Balance accuracy: 0.8793
# F1: 0.8816
#
# Las métricas de evaluación del modelo 194 con estructura  [(100, 100)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.406
# Recall: 0.4
# Balance accuracy: 0.5
# F1: 0.2694
#
# Las métricas de evaluación del modelo 195 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8816666666666666
# Precision: 0.8816
# Recall: 0.896
# Balance accuracy: 0.8836
# F1: 0.8858
#
# Las métricas de evaluación del modelo 196 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.50125
# Precision: 0.4058
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5386
#
# Las métricas de evaluación del modelo 197 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.88125
# Precision: 0.8742
# Recall: 0.9039
# Balance accuracy: 0.8824
# F1: 0.8837
#
# Las métricas de evaluación del modelo 198 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.3044
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.5386
#
# Las métricas de evaluación del modelo 199 con estructura  [(5, 5)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8702777777777777
# Precision: 0.8465
# Recall: 0.824
# Balance accuracy: 0.8743
# F1: 0.8699
#
# Las métricas de evaluación del modelo 200 con estructura  [(5, 5)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 201 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8744444444444444
# Precision: 0.8639
# Recall: 0.9162
# Balance accuracy: 0.8797
# F1: 0.8768
#
# Las métricas de evaluación del modelo 202 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 203 con estructura  [(10, 10)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8754166666666666
# Precision: 0.8725
# Recall: 0.8984
# Balance accuracy: 0.8758
# F1: 0.8784
#
# Las métricas de evaluación del modelo 204 con estructura  [(10, 10)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 205 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8783333333333333
# Precision: 0.8667
# Recall: 0.8965
# Balance accuracy: 0.8809
# F1: 0.8824
#
# Las métricas de evaluación del modelo 206 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 207 con estructura  [(20, 20)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8763888888888889
# Precision: 0.8679
# Recall: 0.8951
# Balance accuracy: 0.8775
# F1: 0.882
#
# Las métricas de evaluación del modelo 208 con estructura  [(20, 20)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 209 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8806944444444443
# Precision: 0.8789
# Recall: 0.9069
# Balance accuracy: 0.8817
# F1: 0.8793
#
# Las métricas de evaluación del modelo 210 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 211 con estructura  [(50, 50)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8797222222222221
# Precision: 0.8737
# Recall: 0.891
# Balance accuracy: 0.8767
# F1: 0.8807
#
# Las métricas de evaluación del modelo 212 con estructura  [(50, 50)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.5015277777777778
# Precision: 0.3044
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 213 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8811111111111112
# Precision: 0.8747
# Recall: 0.8968
# Balance accuracy: 0.8806
# F1: 0.884
# Las métricas de evaluación del modelo 214 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.5043055555555556
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 215 con estructura  [(100, 100)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8793055555555555
# Precision: 0.8748
# Recall: 0.891
# Balance accuracy: 0.8776
# F1: 0.8808
#
# Las métricas de evaluación del modelo 216 con estructura  [(100, 100)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.5045833333333333
# Precision: 0.3044
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 217 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8809722222222222
# Precision: 0.8769
# Recall: 0.9077
# Balance accuracy: 0.8784
# F1: 0.8863
#
# Las métricas de evaluación del modelo 218 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.5015277777777778
# Precision: 0.2029
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 219 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8790277777777777
# Precision: 0.8664
# Recall: 0.9001
# Balance accuracy: 0.8794
# F1: 0.8846
#
# Las métricas de evaluación del modelo 220 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.5045833333333333
# Precision: 0.3043
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5385

# %%
# Se convierten listas en array para las gráficas
contador1=np.asarray(contador1)
acc_list1=np.asarray(acc_list1)
prec_list1=np.asarray(prec_list1)
rec_list1=np.asarray(rec_list1)
bal_acc_list1=np.asarray(bal_acc_list1)
f1_list1=np.array(f1_list1)
                
# crear gráficas superpuestas
plt.plot(contador1,acc_list1, color='b', label='accuracy', marker='o')
plt.plot(contador1,prec_list1, color='g', label='precision')
plt.plot(contador1,rec_list1, color='r', label='recall/TPR')
plt.plot(contador1,bal_acc_list1, color='c', label='balanced accuracy')
plt.plot(contador1,f1_list1, color='y', label='f1')

# nombre de ejes 
plt.xlabel(" ID Modelo")
plt.ylabel("Score/Performance %")
plt.title("Metricas de evaluación de los modelos")

# agregar leyenda, a partir de labels de cada grafica
plt.legend()
# mostrar grafica
plt.show()

# %%
#Implementamos red con los hiperparámetros óptimos encontrados en paso anterior

# crear red neuronal óptima con los hiper parámetros sintonizados
ModeloMF_opt = MLPClassifier(hidden_layer_sizes =hidden_layers_opt1, activation=acts_opt1, alpha=regs_opt1) #Se fijan los hiperparámetros óptimos
# ajustar modelo óptimo con train-set de la base XMF
ModeloMF_opt.fit(XMF_train, y_train) #Se ajusta red con los datos de entrenamiento.

# cear vector de predicciones a partir de x-test
y_predict = ModeloMF_opt.predict(XMF_test)

print('El mejor modelo es el', cont_m1,'que tiene los siguientes hiperparámetros:')
print('Capas ocultas y cantidad de Neuronas:', hidden_layers_opt1)
print('Función de activación:', acts_opt1)
print('Regularización', regs_opt1)

#Almacenamiento Metricas

acc1 = round(accuracy_score(y_test, y_predict),5)
prec1 = round(precision_score(y_test, y_predict),5)
rec1 = round(recall_score(y_test, y_predict),5)
bal1 = round(balanced_accuracy_score(y_test, y_predict),5)
f1_1 = round(f1_score(y_test, y_predict),5)

# calcular metricas de evaluacion
print(f'Accuracy {round(accuracy_score(y_test, y_predict),5)}')
print(f'Precision {round(precision_score(y_test, y_predict),5)}')
print(f'Sensitivity/Recall {round(recall_score(y_test, y_predict),5)}')
print(f'Balanced Accuracy {round(balanced_accuracy_score(y_test, y_predict),5)}')
print(f'F1 {round(f1_score(y_test, y_predict),5)}')


hiperpar1 = {
    'hidden_layers': hidden_layers_opt1,
    'Func_act': acts_opt1,
    'reg': regs_opt1
    }

df_hiperparam1 = pd.DataFrame([[key, hiperpar1[key]] for key in hiperpar1.keys()], columns=['Hiperparámetros '+str(cont_m1), 'Valor'])
df_hiperparam1.to_csv('mejor_HiperparamMF.csv')

modelo1  = {
    "Accuracy": acc1,
         "Precision":prec1,
         "Recall" : rec1,
         "Balanced Accuracy" : bal1,
         "F1": f1_1        
        }

df_metricas1 = pd.DataFrame([[key, modelo1[key]] for key in modelo1.keys()], columns=['Metricas del Modelo '+str(cont_m1), 'Valor'])

df_metricas1.to_csv('mejor_metricasMF.csv')

# crear matriz de confusion
#print(pd.DataFrame(confusion_matrix(y_test,y_predict)))

df_metricas1
# Out:
# El mejor modelo es el 11 que tiene los siguientes hiperparámetros:
# Capas ocultas y cantidad de Neuronas: (20, 20, 20)
# Función de activación: relu
# Regularización 0.0
# Accuracy 0.89778
# Precision 0.89379
# Sensitivity/Recall 0.88744
# Balanced Accuracy 0.89717
# F1 0.89061
#   Metricas del Modelo 11    Valor
# 0               Accuracy  0.89778
# 1              Precision  0.89379
# 2                 Recall  0.88744
# 3      Balanced Accuracy  0.89717
# 4                     F1  0.89061

# %%
Mejor1=pd.read_csv('mejor_metricasMF.csv')
Mejor1
# Out:
#    Unnamed: 0 Metricas del Modelo 11    Valor
# 0           0               Accuracy  0.89778
# 1           1              Precision  0.89379
# 2           2                 Recall  0.88744
# 3           3      Balanced Accuracy  0.89717
# 4           4                     F1  0.89061

# %% [markdown]
# ## Modelos ajustados con variables con poder predictivo medio a fuerte y con una interacciones

# %%
#Se crea un vector con las arquitecturas de red a probar.
Estructura=[(5,5), (5,5,5),(10,10),(10,10,10),(20,20),(20,20,20),(50,50),(50,50,50),(100,100),(100,100,100),(50,10,100)]
Activacion = ['relu','logistic']  #Funciones de activación para probar
alfa = np.linspace(0,3,num=10) #Se generan 10 valores de regularizacion entre 0 y 3.


#Se incializan variables para saber cual es el mejor modelo creado.
accs_opt2 = 0
cont_m2 = None
hidden_layers_opt1 = None
acts_opt2 = None
regs_opt2 = None
# Se crean listas de las métricas de evaluación a graficar.
# crear lista de metricas de evaluacion a graficar
acc_list2 = []
prec_list2 = []
rec_list2 = []
bal_acc_list2 = []
f1_list2 = []
contador2 = []
cont2 = 1 # Contador que nos servira como id del modelo ajustado.
for reg in alfa:
    for est in Estructura:
        for act in Activacion:
            ModeloMFI = MLPClassifier(hidden_layer_sizes = est, activation=act, alpha=reg)
            res_acc = cross_val_score(ModeloMFI,XMFI_train, y_train, scoring='accuracy',n_jobs=-1)
            avg_acc = np.mean(res_acc)
            res_prec = cross_val_score(ModeloMFI,XMFI_train, y_train, scoring='precision',n_jobs=-1)
            avg_prec = round(np.mean(res_prec),4)
            res_rec = cross_val_score(ModeloMFI,XMFI_train, y_train, scoring='recall',n_jobs=-1)
            avg_rec = round(np.mean(res_rec),4)
            res_bal = cross_val_score(ModeloMFI,XMFI_train, y_train, scoring='balanced_accuracy',n_jobs=-1)
            avg_bal = round(np.mean(res_bal),4)
            res_f1 = cross_val_score(ModeloMFI,XMFI_train, y_train, scoring='f1',n_jobs=-1)
            avg_f1 = round(np.mean(res_f1),4)
            
            #Agregamos métricas de evaluación a la listas
            acc_list2.append(avg_acc)
            prec_list2.append(avg_prec)
            rec_list2.append(avg_rec)
            bal_acc_list2.append(avg_bal)
            f1_list2.append(avg_f1)
            contador2.append(cont2)
            
            
            print('Las métricas de evaluación del modelo '+ str(cont2)+' con estructura  [' +str(est)+ '] función de activación ' +str(act) + ' y regularización L2 ' + str(reg)+ ' son:'  )
            print('Accuracy: ' + str(avg_acc))
            print('Precision: ' + str(avg_prec))
            print('Recall: ' + str(avg_rec))
            print('Balance accuracy: ' + str(avg_bal))
            print('F1: ' + str(avg_f1))
            print(' ')
          
            
            #Dado que se evaluará la probabilidad de error del modelo, se escoge el mejor modelo con base en el Accuracy
            if avg_acc > accs_opt2:
                accs_opt2 = avg_acc
                hidden_layers_opt2 = est
                acts_opt2 = act
                regs_opt2 = reg
                cont_m2 = cont2
                  
            cont2 +=1
# Out:
# Las métricas de evaluación del modelo 1 con estructura  [(5, 5)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.882638888888889
# Precision: 0.872
# Recall: 0.8993
# Balance accuracy: 0.8823
# F1: 0.8852
#
# Las métricas de evaluación del modelo 2 con estructura  [(5, 5)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8787500000000001
# Precision: 0.8746
# Recall: 0.9039
# Balance accuracy: 0.8812
# F1: 0.8842
#
# Las métricas de evaluación del modelo 3 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8822222222222222
# Precision: 0.8781
# Recall: 0.896
# Balance accuracy: 0.8809
# F1: 0.8883
#
# Las métricas de evaluación del modelo 4 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8526388888888888
# Precision: 0.8732
# Recall: 0.7674
# Balance accuracy: 0.8259
# F1: 0.8085
#
# Las métricas de evaluación del modelo 5 con estructura  [(10, 10)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8851388888888889
# Precision: 0.8831
# Recall: 0.9036
# Balance accuracy: 0.8888
# F1: 0.8919
#
# Las métricas de evaluación del modelo 6 con estructura  [(10, 10)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8829166666666666
# Precision: 0.8748
# Recall: 0.8962
# Balance accuracy: 0.8839
# F1: 0.8855
#
# Las métricas de evaluación del modelo 7 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.888888888888889
# Precision: 0.883
# Recall: 0.902
# Balance accuracy: 0.8882
# F1: 0.8898
#
# Las métricas de evaluación del modelo 8 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8820833333333333
# Precision: 0.8826
# Recall: 0.8306
# Balance accuracy: 0.8837
# F1: 0.8882
#
# Las métricas de evaluación del modelo 9 con estructura  [(20, 20)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8898611111111112
# Precision: 0.8791
# Recall: 0.9036
# Balance accuracy: 0.8896
# F1: 0.8927
#
# Las métricas de evaluación del modelo 10 con estructura  [(20, 20)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8845833333333333
# Precision: 0.8793
# Recall: 0.8949
# Balance accuracy: 0.8855
# F1: 0.8883
#
# Las métricas de evaluación del modelo 11 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.887361111111111
# Precision: 0.8793
# Recall: 0.9039
# Balance accuracy: 0.8878
# F1: 0.8897
#
# Las métricas de evaluación del modelo 12 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8873611111111112
# Precision: 0.8791
# Recall: 0.8932
# Balance accuracy: 0.8847
# F1: 0.8866
#
# Las métricas de evaluación del modelo 13 con estructura  [(50, 50)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.890138888888889
# Precision: 0.8869
# Recall: 0.9077
# Balance accuracy: 0.887
# F1: 0.8888
#
# Las métricas de evaluación del modelo 14 con estructura  [(50, 50)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8844444444444445
# Precision: 0.8759
# Recall: 0.8965
# Balance accuracy: 0.8833
# F1: 0.8879
#
# Las métricas de evaluación del modelo 15 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8830555555555556
# Precision: 0.8785
# Recall: 0.9135
# Balance accuracy: 0.8865
# F1: 0.8906
#
# Las métricas de evaluación del modelo 16 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8816666666666666
# Precision: 0.8727
# Recall: 0.8902
# Balance accuracy: 0.8834
# F1: 0.8883
#
# Las métricas de evaluación del modelo 17 con estructura  [(100, 100)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8872222222222221
# Precision: 0.8805
# Recall: 0.9091
# Balance accuracy: 0.8879
# F1: 0.8885
#
# Las métricas de evaluación del modelo 18 con estructura  [(100, 100)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8845833333333333
# Precision: 0.8745
# Recall: 0.902
# Balance accuracy: 0.8834
# F1: 0.8861
#
# Las métricas de evaluación del modelo 19 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8848611111111111
# Precision: 0.877
# Recall: 0.9088
# Balance accuracy: 0.883
# F1: 0.8891
#
# Las métricas de evaluación del modelo 20 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.882638888888889
# Precision: 0.874
# Recall: 0.8905
# Balance accuracy: 0.8831
# F1: 0.8872
#
# Las métricas de evaluación del modelo 21 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 0.0 son:
# Accuracy: 0.8848611111111111
# Precision: 0.8756
# Recall: 0.9088
# Balance accuracy: 0.8883
# F1: 0.89
#
# Las métricas de evaluación del modelo 22 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 0.0 son:
# Accuracy: 0.8841666666666667
# Precision: 0.8805
# Recall: 0.8927
# Balance accuracy: 0.8842
# F1: 0.887
#
# Las métricas de evaluación del modelo 23 con estructura  [(5, 5)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.88375
# Precision: 0.8762
# Recall: 0.9042
# Balance accuracy: 0.8808
# F1: 0.8845
#
# Las métricas de evaluación del modelo 24 con estructura  [(5, 5)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8731944444444444
# Precision: 0.8589
# Recall: 0.8943
# Balance accuracy: 0.8731
# F1: 0.8778
#
# Las métricas de evaluación del modelo 25 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8862499999999999
# Precision: 0.881
# Recall: 0.9004
# Balance accuracy: 0.8856
# F1: 0.8867
#
# Las métricas de evaluación del modelo 26 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5736
# F1: 0.6732
#
# Las métricas de evaluación del modelo 27 con estructura  [(10, 10)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.888888888888889
# Precision: 0.8822
# Recall: 0.905
# Balance accuracy: 0.8875
# F1: 0.8886
#
# Las métricas de evaluación del modelo 28 con estructura  [(10, 10)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8743055555555556
# Precision: 0.8645
# Recall: 0.8973
# Balance accuracy: 0.8743
# F1: 0.8796
#
# Las métricas de evaluación del modelo 29 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8845833333333333
# Precision: 0.8885
# Recall: 0.9034
# Balance accuracy: 0.8896
# F1: 0.8907
#
# Las métricas de evaluación del modelo 30 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5786
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 31 con estructura  [(20, 20)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8862499999999999
# Precision: 0.887
# Recall: 0.9102
# Balance accuracy: 0.8898
# F1: 0.8912
#
# Las métricas de evaluación del modelo 32 con estructura  [(20, 20)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.87375
# Precision: 0.8624
# Recall: 0.899
# Balance accuracy: 0.8775
# F1: 0.8812
#
# Las métricas de evaluación del modelo 33 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8901388888888888
# Precision: 0.8792
# Recall: 0.8913
# Balance accuracy: 0.89
# F1: 0.8947
#
# Las métricas de evaluación del modelo 34 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 35 con estructura  [(50, 50)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8897222222222222
# Precision: 0.8786
# Recall: 0.8998
# Balance accuracy: 0.8882
# F1: 0.8928
#
# Las métricas de evaluación del modelo 36 con estructura  [(50, 50)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8729166666666666
# Precision: 0.8465
# Recall: 0.8888
# Balance accuracy: 0.8661
# F1: 0.8654
# Las métricas de evaluación del modelo 37 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8873611111111112
# Precision: 0.8821
# Recall: 0.8998
# Balance accuracy: 0.8875
# F1: 0.8934
#
# Las métricas de evaluación del modelo 38 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.49847222222222226
# Precision: 0.4058
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 39 con estructura  [(100, 100)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8901388888888888
# Precision: 0.8811
# Recall: 0.9003
# Balance accuracy: 0.8887
# F1: 0.8945
#
# Las métricas de evaluación del modelo 40 con estructura  [(100, 100)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8570833333333333
# Precision: 0.8504
# Recall: 0.8826
# Balance accuracy: 0.8631
# F1: 0.8685
#
# Las métricas de evaluación del modelo 41 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8851388888888888
# Precision: 0.8805
# Recall: 0.8962
# Balance accuracy: 0.8888
# F1: 0.8918
#
# Las métricas de evaluación del modelo 42 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.5043055555555556
# Precision: 0.406
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 43 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 0.3333333333333333 son:
# Accuracy: 0.8875
# Precision: 0.8823
# Recall: 0.8971
# Balance accuracy: 0.8875
# F1: 0.8901
#
# Las métricas de evaluación del modelo 44 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 0.3333333333333333 son:
# Accuracy: 0.5045833333333333
# Precision: 0.3044
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 45 con estructura  [(5, 5)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8827777777777778
# Precision: 0.8682
# Recall: 0.9012
# Balance accuracy: 0.8822
# F1: 0.884
#
# Las métricas de evaluación del modelo 46 con estructura  [(5, 5)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8612500000000001
# Precision: 0.85
# Recall: 0.8817
# Balance accuracy: 0.863
# F1: 0.8663
#
# Las métricas de evaluación del modelo 47 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8852777777777778
# Precision: 0.8818
# Recall: 0.9003
# Balance accuracy: 0.8814
# F1: 0.8887
#
# Las métricas de evaluación del modelo 48 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 49 con estructura  [(10, 10)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8858333333333333
# Precision: 0.89
# Recall: 0.9017
# Balance accuracy: 0.886
# F1: 0.8901
#
# Las métricas de evaluación del modelo 50 con estructura  [(10, 10)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8608333333333332
# Precision: 0.85
# Recall: 0.8787
# Balance accuracy: 0.8614
# F1: 0.8685
#
# Las métricas de evaluación del modelo 51 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8841666666666667
# Precision: 0.8791
# Recall: 0.9099
# Balance accuracy: 0.8888
# F1: 0.8912
#
# Las métricas de evaluación del modelo 52 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 53 con estructura  [(20, 20)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8870833333333333
# Precision: 0.8888
# Recall: 0.9017
# Balance accuracy: 0.8859
# F1: 0.8922
#
# Las métricas de evaluación del modelo 54 con estructura  [(20, 20)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8620833333333333
# Precision: 0.8506
# Recall: 0.8831
# Balance accuracy: 0.8628
# F1: 0.865
#
# Las métricas de evaluación del modelo 55 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8897222222222222
# Precision: 0.8803
# Recall: 0.8965
# Balance accuracy: 0.889
# F1: 0.8925
#
# Las métricas de evaluación del modelo 56 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 57 con estructura  [(50, 50)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8898611111111112
# Precision: 0.8844
# Recall: 0.8951
# Balance accuracy: 0.8891
# F1: 0.893
#
# Las métricas de evaluación del modelo 58 con estructura  [(50, 50)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8613888888888889
# Precision: 0.8431
# Recall: 0.8763
# Balance accuracy: 0.8606
# F1: 0.8664
#
# Las métricas de evaluación del modelo 59 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8887500000000002
# Precision: 0.894
# Recall: 0.9003
# Balance accuracy: 0.8909
# F1: 0.8906
#
# Las métricas de evaluación del modelo 60 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.50125
# Precision: 0.5074
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5386
#
# Las métricas de evaluación del modelo 61 con estructura  [(100, 100)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8898611111111112
# Precision: 0.8889
# Recall: 0.8916
# Balance accuracy: 0.8877
# F1: 0.8915
#
# Las métricas de evaluación del modelo 62 con estructura  [(100, 100)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8619444444444445
# Precision: 0.8424
# Recall: 0.8842
# Balance accuracy: 0.8548
# F1: 0.8638
#
# Las métricas de evaluación del modelo 63 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8876388888888889
# Precision: 0.8894
# Recall: 0.9075
# Balance accuracy: 0.8886
# F1: 0.8929
#
# Las métricas de evaluación del modelo 64 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.507361111111111
# Precision: 0.4058
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 65 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 0.6666666666666666 son:
# Accuracy: 0.8886111111111111
# Precision: 0.881
# Recall: 0.9053
# Balance accuracy: 0.8877
# F1: 0.8916
#
# Las métricas de evaluación del modelo 66 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 0.6666666666666666 son:
# Accuracy: 0.49847222222222226
# Precision: 0.5074
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 67 con estructura  [(5, 5)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8800000000000001
# Precision: 0.8712
# Recall: 0.9058
# Balance accuracy: 0.8786
# F1: 0.887
#
# Las métricas de evaluación del modelo 68 con estructura  [(5, 5)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.7188888888888889
# Precision: 0.8493
# Recall: 0.8801
# Balance accuracy: 0.7883
# F1: 0.7947
#
# Las métricas de evaluación del modelo 69 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8829166666666668
# Precision: 0.8755
# Recall: 0.899
# Balance accuracy: 0.8835
# F1: 0.8839
#
# Las métricas de evaluación del modelo 70 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 71 con estructura  [(10, 10)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8866666666666667
# Precision: 0.8723
# Recall: 0.9067
# Balance accuracy: 0.883
# F1: 0.8881
# Las métricas de evaluación del modelo 72 con estructura  [(10, 10)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.8588888888888888
# Precision: 0.8468
# Recall: 0.911
# Balance accuracy: 0.857
# F1: 0.863
#
# Las métricas de evaluación del modelo 73 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.887361111111111
# Precision: 0.877
# Recall: 0.8987
# Balance accuracy: 0.8887
# F1: 0.8891
#
# Las métricas de evaluación del modelo 74 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 75 con estructura  [(20, 20)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.887361111111111
# Precision: 0.8706
# Recall: 0.9009
# Balance accuracy: 0.8868
# F1: 0.8904
#
# Las métricas de evaluación del modelo 76 con estructura  [(20, 20)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.8581944444444446
# Precision: 0.8485
# Recall: 0.8916
# Balance accuracy: 0.8587
# F1: 0.8641
#
# Las métricas de evaluación del modelo 77 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8879166666666667
# Precision: 0.8758
# Recall: 0.902
# Balance accuracy: 0.8869
# F1: 0.8917
#
# Las métricas de evaluación del modelo 78 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.5045833333333333
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 79 con estructura  [(50, 50)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8890277777777778
# Precision: 0.8886
# Recall: 0.893
# Balance accuracy: 0.8892
# F1: 0.8909
#
# Las métricas de evaluación del modelo 80 con estructura  [(50, 50)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.8526388888888888
# Precision: 0.8231
# Recall: 0.8834
# Balance accuracy: 0.8539
# F1: 0.8593
#
# Las métricas de evaluación del modelo 81 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8887500000000002
# Precision: 0.8813
# Recall: 0.9266
# Balance accuracy: 0.8891
# F1: 0.8913
#
# Las métricas de evaluación del modelo 82 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.50125
# Precision: 0.5074
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 83 con estructura  [(100, 100)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8887499999999999
# Precision: 0.878
# Recall: 0.9077
# Balance accuracy: 0.8878
# F1: 0.8921
#
# Las métricas de evaluación del modelo 84 con estructura  [(100, 100)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.8502777777777778
# Precision: 0.8522
# Recall: 0.9039
# Balance accuracy: 0.8502
# F1: 0.8567
#
# Las métricas de evaluación del modelo 85 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8897222222222222
# Precision: 0.8934
# Recall: 0.9031
# Balance accuracy: 0.8903
# F1: 0.8924
#
# Las métricas de evaluación del modelo 86 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.5045833333333333
# Precision: 0.2031
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.4038
#
# Las métricas de evaluación del modelo 87 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 1.0 son:
# Accuracy: 0.8883333333333333
# Precision: 0.8839
# Recall: 0.9034
# Balance accuracy: 0.8882
# F1: 0.8926
#
# Las métricas de evaluación del modelo 88 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 1.0 son:
# Accuracy: 0.5045833333333333
# Precision: 0.3043
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 89 con estructura  [(5, 5)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8780555555555555
# Precision: 0.8672
# Recall: 0.9025
# Balance accuracy: 0.88
# F1: 0.8861
#
# Las métricas de evaluación del modelo 90 con estructura  [(5, 5)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.7345833333333334
# Precision: 0.5753
# Recall: 0.9198
# Balance accuracy: 0.7142
# F1: 0.7467
#
# Las métricas de evaluación del modelo 91 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8795833333333334
# Precision: 0.8822
# Recall: 0.8935
# Balance accuracy: 0.8802
# F1: 0.8855
#
# Las métricas de evaluación del modelo 92 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 93 con estructura  [(10, 10)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8845833333333333
# Precision: 0.8753
# Recall: 0.8995
# Balance accuracy: 0.8848
# F1: 0.8864
#
# Las métricas de evaluación del modelo 94 con estructura  [(10, 10)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8163888888888888
# Precision: 0.7772
# Recall: 0.9255
# Balance accuracy: 0.8536
# F1: 0.7497
#
# Las métricas de evaluación del modelo 95 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8888888888888887
# Precision: 0.8774
# Recall: 0.9012
# Balance accuracy: 0.8879
# F1: 0.8875
#
# Las métricas de evaluación del modelo 96 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 97 con estructura  [(20, 20)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8843055555555555
# Precision: 0.8764
# Recall: 0.9031
# Balance accuracy: 0.8842
# F1: 0.8878
#
# Las métricas de evaluación del modelo 98 con estructura  [(20, 20)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.7811111111111111
# Precision: 0.7689
# Recall: 0.9061
# Balance accuracy: 0.8543
# F1: 0.8523
#
# Las métricas de evaluación del modelo 99 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8893055555555556
# Precision: 0.8872
# Recall: 0.8973
# Balance accuracy: 0.8901
# F1: 0.8919
#
# Las métricas de evaluación del modelo 100 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.4058
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 101 con estructura  [(50, 50)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8863888888888887
# Precision: 0.8848
# Recall: 0.8984
# Balance accuracy: 0.888
# F1: 0.8887
#
# Las métricas de evaluación del modelo 102 con estructura  [(50, 50)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8533333333333333
# Precision: 0.8356
# Recall: 0.8809
# Balance accuracy: 0.8487
# F1: 0.8542
#
# Las métricas de evaluación del modelo 103 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8904166666666666
# Precision: 0.8843
# Recall: 0.8965
# Balance accuracy: 0.8877
# F1: 0.8917
#
# Las métricas de evaluación del modelo 104 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.4058
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 105 con estructura  [(100, 100)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8876388888888889
# Precision: 0.882
# Recall: 0.89
# Balance accuracy: 0.8872
# F1: 0.8902
#
# Las métricas de evaluación del modelo 106 con estructura  [(100, 100)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8443055555555554
# Precision: 0.8286
# Recall: 0.885
# Balance accuracy: 0.8519
# F1: 0.8573
#
# Las métricas de evaluación del modelo 107 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8868055555555555
# Precision: 0.8753
# Recall: 0.9066
# Balance accuracy: 0.8894
# F1: 0.8937
# Las métricas de evaluación del modelo 108 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.5043055555555556
# Precision: 0.406
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 109 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 1.3333333333333333 son:
# Accuracy: 0.8883333333333333
# Precision: 0.8861
# Recall: 0.8995
# Balance accuracy: 0.8898
# F1: 0.8922
#
# Las métricas de evaluación del modelo 110 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 1.3333333333333333 son:
# Accuracy: 0.5043055555555556
# Precision: 0.2029
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 111 con estructura  [(5, 5)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8780555555555555
# Precision: 0.8701
# Recall: 0.8938
# Balance accuracy: 0.8759
# F1: 0.8828
#
# Las métricas de evaluación del modelo 112 con estructura  [(5, 5)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.6256
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6927
#
# Las métricas de evaluación del modelo 113 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8826388888888888
# Precision: 0.8701
# Recall: 0.8993
# Balance accuracy: 0.8795
# F1: 0.8869
#
# Las métricas de evaluación del modelo 114 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 115 con estructura  [(10, 10)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8816666666666666
# Precision: 0.867
# Recall: 0.8962
# Balance accuracy: 0.8823
# F1: 0.8859
#
# Las métricas de evaluación del modelo 116 con estructura  [(10, 10)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5076
# Recall: 1.0
# Balance accuracy: 0.5661
# F1: 0.742
#
# Las métricas de evaluación del modelo 117 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.887361111111111
# Precision: 0.8825
# Recall: 0.9006
# Balance accuracy: 0.8832
# F1: 0.8885
#
# Las métricas de evaluación del modelo 118 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 119 con estructura  [(20, 20)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8863888888888889
# Precision: 0.8804
# Recall: 0.9047
# Balance accuracy: 0.885
# F1: 0.8847
#
# Las métricas de evaluación del modelo 120 con estructura  [(20, 20)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.6404166666666666
# Precision: 0.6847
# Recall: 0.9496
# Balance accuracy: 0.699
# F1: 0.8107
#
# Las métricas de evaluación del modelo 121 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.887361111111111
# Precision: 0.8859
# Recall: 0.9012
# Balance accuracy: 0.8878
# F1: 0.8905
#
# Las métricas de evaluación del modelo 122 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 123 con estructura  [(50, 50)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8854166666666666
# Precision: 0.8774
# Recall: 0.9075
# Balance accuracy: 0.885
# F1: 0.8876
#
# Las métricas de evaluación del modelo 124 con estructura  [(50, 50)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.6731944444444444
# Precision: 0.7657
# Recall: 0.8618
# Balance accuracy: 0.7035
# F1: 0.6402
#
# Las métricas de evaluación del modelo 125 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8877777777777778
# Precision: 0.8736
# Recall: 0.8916
# Balance accuracy: 0.8872
# F1: 0.8895
#
# Las métricas de evaluación del modelo 126 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.5045833333333333
# Precision: 0.5074
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 127 con estructura  [(100, 100)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8876388888888889
# Precision: 0.8742
# Recall: 0.9012
# Balance accuracy: 0.8842
# F1: 0.8886
#
# Las métricas de evaluación del modelo 128 con estructura  [(100, 100)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8440277777777778
# Precision: 0.8148
# Recall: 0.8886
# Balance accuracy: 0.8422
# F1: 0.846
#
# Las métricas de evaluación del modelo 129 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8893055555555556
# Precision: 0.8926
# Recall: 0.8976
# Balance accuracy: 0.8896
# F1: 0.8906
#
# Las métricas de evaluación del modelo 130 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.5015277777777778
# Precision: 0.2029
# Recall: 0.4
# Balance accuracy: 0.5
# F1: 0.5386
#
# Las métricas de evaluación del modelo 131 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 1.6666666666666665 son:
# Accuracy: 0.8872222222222221
# Precision: 0.8807
# Recall: 0.9025
# Balance accuracy: 0.8869
# F1: 0.8914
#
# Las métricas de evaluación del modelo 132 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 1.6666666666666665 son:
# Accuracy: 0.5043055555555556
# Precision: 0.3044
# Recall: 0.2
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 133 con estructura  [(5, 5)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8798611111111111
# Precision: 0.8692
# Recall: 0.9006
# Balance accuracy: 0.8822
# F1: 0.8839
#
# Las métricas de evaluación del modelo 134 con estructura  [(5, 5)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 135 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8065277777777778
# Precision: 0.8735
# Recall: 0.9036
# Balance accuracy: 0.8792
# F1: 0.8864
#
# Las métricas de evaluación del modelo 136 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 137 con estructura  [(10, 10)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8823611111111112
# Precision: 0.8727
# Recall: 0.8982
# Balance accuracy: 0.8797
# F1: 0.8843
#
# Las métricas de evaluación del modelo 138 con estructura  [(10, 10)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 139 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8859722222222223
# Precision: 0.8748
# Recall: 0.8987
# Balance accuracy: 0.8845
# F1: 0.8881
#
# Las métricas de evaluación del modelo 140 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 141 con estructura  [(20, 20)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8826388888888888
# Precision: 0.8737
# Recall: 0.8993
# Balance accuracy: 0.8818
# F1: 0.8864
#
# Las métricas de evaluación del modelo 142 con estructura  [(20, 20)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
# Las métricas de evaluación del modelo 143 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8869444444444443
# Precision: 0.8752
# Recall: 0.8897
# Balance accuracy: 0.8864
# F1: 0.889
#
# Las métricas de evaluación del modelo 144 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 145 con estructura  [(50, 50)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.88375
# Precision: 0.8724
# Recall: 0.9025
# Balance accuracy: 0.8836
# F1: 0.886
#
# Las métricas de evaluación del modelo 146 con estructura  [(50, 50)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.50125
# Precision: 0.2028
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5386
#
# Las métricas de evaluación del modelo 147 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8875
# Precision: 0.883
# Recall: 0.9004
# Balance accuracy: 0.8874
# F1: 0.8911
#
# Las métricas de evaluación del modelo 148 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.5015277777777778
# Precision: 0.5074
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.5385
#
# Las métricas de evaluación del modelo 149 con estructura  [(100, 100)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8852777777777776
# Precision: 0.8752
# Recall: 0.8963
# Balance accuracy: 0.8831
# F1: 0.8872
#
# Las métricas de evaluación del modelo 150 con estructura  [(100, 100)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.5015277777777778
# Precision: 0.3043
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.5322
#
# Las métricas de evaluación del modelo 151 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8880555555555555
# Precision: 0.8825
# Recall: 0.8899
# Balance accuracy: 0.8839
# F1: 0.8914
#
# Las métricas de evaluación del modelo 152 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.5043055555555556
# Precision: 0.2029
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.2692
#
# Las métricas de evaluación del modelo 153 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 2.0 son:
# Accuracy: 0.8844444444444445
# Precision: 0.8868
# Recall: 0.9047
# Balance accuracy: 0.8872
# F1: 0.8908
#
# Las métricas de evaluación del modelo 154 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 2.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.3044
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.2694
#
# Las métricas de evaluación del modelo 155 con estructura  [(5, 5)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8779166666666667
# Precision: 0.87
# Recall: 0.899
# Balance accuracy: 0.8799
# F1: 0.8818
#
# Las métricas de evaluación del modelo 156 con estructura  [(5, 5)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 157 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8777777777777779
# Precision: 0.871
# Recall: 0.8902
# Balance accuracy: 0.8794
# F1: 0.8844
#
# Las métricas de evaluación del modelo 158 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 159 con estructura  [(10, 10)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8809722222222222
# Precision: 0.8694
# Recall: 0.8946
# Balance accuracy: 0.8799
# F1: 0.8862
#
# Las métricas de evaluación del modelo 160 con estructura  [(10, 10)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 161 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.88125
# Precision: 0.8747
# Recall: 0.9034
# Balance accuracy: 0.8846
# F1: 0.8859
#
# Las métricas de evaluación del modelo 162 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 163 con estructura  [(20, 20)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8800000000000001
# Precision: 0.869
# Recall: 0.8993
# Balance accuracy: 0.8787
# F1: 0.8856
#
# Las métricas de evaluación del modelo 164 con estructura  [(20, 20)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 165 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8849999999999998
# Precision: 0.8776
# Recall: 0.8987
# Balance accuracy: 0.884
# F1: 0.888
#
# Las métricas de evaluación del modelo 166 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 167 con estructura  [(50, 50)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.883611111111111
# Precision: 0.8679
# Recall: 0.8993
# Balance accuracy: 0.8815
# F1: 0.8862
#
# Las métricas de evaluación del modelo 168 con estructura  [(50, 50)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.50125
# Precision: 0.3044
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.2692
#
# Las métricas de evaluación del modelo 169 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8875
# Precision: 0.879
# Recall: 0.8908
# Balance accuracy: 0.8851
# F1: 0.8912
#
# Las métricas de evaluación del modelo 170 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.5045833333333333
# Precision: 0.3044
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.5386
#
# Las métricas de evaluación del modelo 171 con estructura  [(100, 100)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8816666666666666
# Precision: 0.8703
# Recall: 0.8982
# Balance accuracy: 0.8817
# F1: 0.8849
#
# Las métricas de evaluación del modelo 172 con estructura  [(100, 100)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.50125
# Precision: 0.2029
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.4041
#
# Las métricas de evaluación del modelo 173 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8877777777777778
# Precision: 0.8815
# Recall: 0.9154
# Balance accuracy: 0.8854
# F1: 0.886
#
# Las métricas de evaluación del modelo 174 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.5043055555555556
# Precision: 0.406
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 175 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 2.333333333333333 son:
# Accuracy: 0.8865277777777779
# Precision: 0.8735
# Recall: 0.9047
# Balance accuracy: 0.8861
# F1: 0.889
#
# Las métricas de evaluación del modelo 176 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 2.333333333333333 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.2692
#
# Las métricas de evaluación del modelo 177 con estructura  [(5, 5)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8745833333333334
# Precision: 0.8708
# Recall: 0.9031
# Balance accuracy: 0.8749
# F1: 0.8823
#
# Las métricas de evaluación del modelo 178 con estructura  [(5, 5)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
# Las métricas de evaluación del modelo 179 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8802777777777777
# Precision: 0.8677
# Recall: 0.8938
# Balance accuracy: 0.8769
# F1: 0.8813
#
# Las métricas de evaluación del modelo 180 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 181 con estructura  [(10, 10)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8800000000000001
# Precision: 0.8685
# Recall: 0.9012
# Balance accuracy: 0.8782
# F1: 0.882
#
# Las métricas de evaluación del modelo 182 con estructura  [(10, 10)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 183 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8827777777777778
# Precision: 0.8739
# Recall: 0.8968
# Balance accuracy: 0.8848
# F1: 0.8847
#
# Las métricas de evaluación del modelo 184 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 185 con estructura  [(20, 20)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8798611111111111
# Precision: 0.8674
# Recall: 0.9006
# Balance accuracy: 0.8801
# F1: 0.8836
#
# Las métricas de evaluación del modelo 186 con estructura  [(20, 20)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 187 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8847222222222222
# Precision: 0.8855
# Recall: 0.9014
# Balance accuracy: 0.885
# F1: 0.8892
#
# Las métricas de evaluación del modelo 188 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 189 con estructura  [(50, 50)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8802777777777777
# Precision: 0.868
# Recall: 0.902
# Balance accuracy: 0.8822
# F1: 0.8858
#
# Las métricas de evaluación del modelo 190 con estructura  [(50, 50)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.5045833333333333
# Precision: 0.4058
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 191 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8833333333333334
# Precision: 0.867
# Recall: 0.8979
# Balance accuracy: 0.8839
# F1: 0.888
#
# Las métricas de evaluación del modelo 192 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.5045833333333333
# Precision: 0.4058
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.5386
#
# Las métricas de evaluación del modelo 193 con estructura  [(100, 100)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8801388888888889
# Precision: 0.8752
# Recall: 0.9004
# Balance accuracy: 0.8783
# F1: 0.8847
#
# Las métricas de evaluación del modelo 194 con estructura  [(100, 100)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.50125
# Precision: 0.5074
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 195 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8855555555555557
# Precision: 0.8688
# Recall: 0.8949
# Balance accuracy: 0.8847
# F1: 0.8893
#
# Las métricas de evaluación del modelo 196 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.5015277777777778
# Precision: 0.4058
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 197 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 2.6666666666666665 son:
# Accuracy: 0.8861111111111111
# Precision: 0.8764
# Recall: 0.9031
# Balance accuracy: 0.8827
# F1: 0.8892
#
# Las métricas de evaluación del modelo 198 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 2.6666666666666665 son:
# Accuracy: 0.5018055555555555
# Precision: 0.4058
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 199 con estructura  [(5, 5)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.877361111111111
# Precision: 0.8644
# Recall: 0.8965
# Balance accuracy: 0.8727
# F1: 0.8804
#
# Las métricas de evaluación del modelo 200 con estructura  [(5, 5)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 201 con estructura  [(5, 5, 5)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8811111111111112
# Precision: 0.7987
# Recall: 0.8941
# Balance accuracy: 0.8788
# F1: 0.8832
#
# Las métricas de evaluación del modelo 202 con estructura  [(5, 5, 5)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 203 con estructura  [(10, 10)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8781944444444445
# Precision: 0.8663
# Recall: 0.9003
# Balance accuracy: 0.8787
# F1: 0.8827
#
# Las métricas de evaluación del modelo 204 con estructura  [(10, 10)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 205 con estructura  [(10, 10, 10)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8816666666666666
# Precision: 0.8677
# Recall: 0.8979
# Balance accuracy: 0.8824
# F1: 0.8849
#
# Las métricas de evaluación del modelo 206 con estructura  [(10, 10, 10)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 207 con estructura  [(20, 20)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8779166666666667
# Precision: 0.8676
# Recall: 0.8993
# Balance accuracy: 0.8786
# F1: 0.8841
#
# Las métricas de evaluación del modelo 208 con estructura  [(20, 20)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 209 con estructura  [(20, 20, 20)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.882638888888889
# Precision: 0.8677
# Recall: 0.8946
# Balance accuracy: 0.882
# F1: 0.8855
#
# Las métricas de evaluación del modelo 210 con estructura  [(20, 20, 20)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.5074
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 211 con estructura  [(50, 50)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8798611111111111
# Precision: 0.8691
# Recall: 0.9004
# Balance accuracy: 0.8798
# F1: 0.8836
#
# Las métricas de evaluación del modelo 212 con estructura  [(50, 50)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.507361111111111
# Precision: 0.4058
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.6732
#
# Las métricas de evaluación del modelo 213 con estructura  [(50, 50, 50)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8816666666666666
# Precision: 0.8694
# Recall: 0.905
# Balance accuracy: 0.8833
# F1: 0.8879
#
# Las métricas de evaluación del modelo 214 con estructura  [(50, 50, 50)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.5043055555555556
# Precision: 0.4058
# Recall: 1.0
# Balance accuracy: 0.5
# F1: 0.6732
# Las métricas de evaluación del modelo 215 con estructura  [(100, 100)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8799999999999999
# Precision: 0.8683
# Recall: 0.902
# Balance accuracy: 0.8796
# F1: 0.8838
#
# Las métricas de evaluación del modelo 216 con estructura  [(100, 100)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.4981944444444445
# Precision: 0.4058
# Recall: 0.8
# Balance accuracy: 0.5
# F1: 0.5386
#
# Las métricas de evaluación del modelo 217 con estructura  [(100, 100, 100)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8847222222222222
# Precision: 0.8672
# Recall: 0.8998
# Balance accuracy: 0.8815
# F1: 0.8868
#
# Las métricas de evaluación del modelo 218 con estructura  [(100, 100, 100)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.5043055555555556
# Precision: 0.5074
# Recall: 0.6
# Balance accuracy: 0.5
# F1: 0.4039
#
# Las métricas de evaluación del modelo 219 con estructura  [(50, 10, 100)] función de activación relu y regularización L2 3.0 son:
# Accuracy: 0.8837499999999998
# Precision: 0.8778
# Recall: 0.905
# Balance accuracy: 0.8832
# F1: 0.8869
#
# Las métricas de evaluación del modelo 220 con estructura  [(50, 10, 100)] función de activación logistic y regularización L2 3.0 son:
# Accuracy: 0.49847222222222226
# Precision: 0.3046
# Recall: 0.0
# Balance accuracy: 0.5
# F1: 0.4039

# %%
# Se convierten listas en array para las gráficas
contador2=np.asarray(contador2)
acc_list2=np.asarray(acc_list2)
prec_list2=np.asarray(prec_list2)
rec_list2=np.asarray(rec_list2)
bal_acc_list2=np.asarray(bal_acc_list2)
f1_list2=np.array(f1_list2)
                
# crear gráficas superpuestas
plt.plot(contador2,acc_list2, color='b', label='accuracy', marker='o')
plt.plot(contador2,prec_list2, color='g', label='precision')
plt.plot(contador2,rec_list2, color='r', label='recall/TPR')
plt.plot(contador2,bal_acc_list2, color='c', label='balanced accuracy')
plt.plot(contador2,f1_list2, color='y', label='f1')

# nombre de ejes 
plt.xlabel(" ID Modelo")
plt.ylabel("Score/Performance %")
plt.title("Metricas de evaluación de los modelos")

# agregar leyenda, a partir de labels de cada grafica
plt.legend()
# mostrar grafica
plt.show()

# %%
#Implementamos red con los hiperparámetros óptimos encontrados en paso anterior

# crear red neuronal óptima con los hiper parámetros sintonizados
ModeloMFI_opt = MLPClassifier(hidden_layer_sizes =hidden_layers_opt2, activation=acts_opt2, alpha=regs_opt2) #Se fijan los hiperparámetros óptimos
# ajustar modelo óptimo con train-set de la base XMF
ModeloMFI_opt.fit(XMFI_train, y_train) #Se ajusta red con los datos de entrenamiento.

# cear vector de predicciones a partir de x-test
y_predict = ModeloMFI_opt.predict(XMFI_test)

print('El mejor modelo es el', cont_m2,'que tiene los siguientes hiperparámetros:')
print('Capas ocultas y cantidad de Neuronas:', hidden_layers_opt2)
print('Función de activación:', acts_opt2)
print('Regularización', regs_opt2)

#Almacenamiento Metricas

acc2 = round(accuracy_score(y_test, y_predict),5)
prec2 = round(precision_score(y_test, y_predict),5)
rec2 = round(recall_score(y_test, y_predict),5)
bal2 = round(balanced_accuracy_score(y_test, y_predict),5)
f1_2 = round(f1_score(y_test, y_predict),5)

# calcular metricas de evaluacion
print(f'Accuracy {round(accuracy_score(y_test, y_predict),5)}')
print(f'Precision {round(precision_score(y_test, y_predict),5)}')
print(f'Sensitivity/Recall {round(recall_score(y_test, y_predict),5)}')
print(f'Balanced Accuracy {round(balanced_accuracy_score(y_test, y_predict),5)}')
print(f'F1 {round(f1_score(y_test, y_predict),5)}')


# crear matriz de confusion
print(pd.DataFrame(confusion_matrix(y_test,y_predict)))

hiperpar2 ={
    'hidden_layers': hidden_layers_opt2,
    'Func_act': acts_opt2,
    'reg': regs_opt2}

df_hiperparam1 = pd.DataFrame([[key, hiperpar2[key]] for key in hiperpar2.keys()], columns=['Hiperparametros '+str(cont_m2), 'Valor'])
df_hiperparam1.to_csv('mejor_HiperparamMF.csv')

modelo2  = {
    "Accuracy": acc2,
         "Precision":prec2,
         "Recall" : rec2,
         "Balanced Accuracy" : bal2,
         "F1": f1_2        
        }

df_metricas2 = pd.DataFrame([[key, modelo2[key]] for key in modelo2.keys()], columns=['Metricas del Modelo '+str(cont_m2), 'Valor'])

df_metricas2.to_csv('mejor_metricasMFI.csv')
# Out:
# El mejor modelo es el 103 que tiene los siguientes hiperparámetros:
# Capas ocultas y cantidad de Neuronas: (50, 50, 50)
# Función de activación: relu
# Regularización 1.3333333333333333
# Accuracy 0.89278
# Precision 0.872
# Sensitivity/Recall 0.90403
# Balanced Accuracy 0.89344
# F1 0.88773
#      0    1
# 0  844  112
# 1   81  763

# %%
df_hiperparam1

# %%
df_metricas2

# %% [markdown]
# # Comparación de los mejores modelos de cada grupo y selección del mejor general

# %%
df_metricas
# Out:
#    Unnamed: 0 Metricas del Modelo 11    Valor  Valor Modelo 11  Unnamed: 0  \
# 0           0               Accuracy  0.89778          0.89778           0
# 1           1              Precision  0.89379          0.89379           1
# 2           2                 Recall  0.88744          0.88744           2
# 3           3      Balanced Accuracy  0.89717          0.89717           3
# 4           4                     F1  0.89061          0.89061           4
#
#   Metricas del Modelo 103    Valor  Valor Modelo 103
# 0                Accuracy  0.89278           0.89278
# 1               Precision  0.87200           0.87200
# 2                  Recall  0.90403           0.90403
# 3       Balanced Accuracy  0.89344           0.89344
# 4                      F1  0.88773           0.88773

# %%
# cargar DataFrames de metricas de evaluacion de mejores modelos de grupos MF y MFI

df_metricas_mf = pd.read_csv("mejor_metricasMF.csv")
df_metricas_mfi = pd.read_csv("mejor_metricasMFI.csv")

# cargar DataFrames de hiper parámetros óptimos de modelos de grupos MF y MFI

df_hiperparam_mf = pd.read_csv("mejor_HiperparamMF.csv")

df_hiperparam_mfi = pd.read_csv("mejor_HiperparamMFI.csv")



# cambiar nombre de columnas de df_metricas_mf y df_metricas_mfi para las gráficas
df_metricas_mf['Valor Modelo 11'] = df_metricas_mf['Valor']
df_metricas_mfi['Valor Modelo 103'] = df_metricas_mfi['Valor']

# concaternar df_metricas_mf y df_metricas_mfi
df_metricas = pd.concat([df_metricas_mf, df_metricas_mfi], axis=1)

metricas = df_metricas['Metricas del Modelo 11']

# crear eje x de metricas
x_axis = np.arange(len(metricas))

# plot metricas de evaluacion de mejores modelos de MF y MFI
plt.bar(x_axis - 0.2, df_metricas['Valor Modelo 11'], 0.4, label = 'MF')
plt.bar(x_axis + 0.2, df_metricas['Valor Modelo 103'], 0.4, label = 'MFI')


# personalizar gráfico
plt.xticks(x_axis, metricas)

plt.xlabel("Metricas de Evaluación")
plt.ylabel("Score/Performance")
plt.title("Métricas de evaluación: Mejores modelos MF y MFI")

# agregar leyenda y mostrar plot
plt.legend()
plt.show()

# %%
df_hiperparam_mf
# Out:
#    Unnamed: 0 Hiperparámetros 11         Valor
# 0           0      hidden_layers  (20, 20, 20)
# 1           1           Func_act          relu
# 2           2                reg           0.0

# %%
df_hiperparam_mfi
# Out:
#    Unnamed: 0 Hiperparámetros 103               Valor
# 0           0       hidden_layers        (50, 50, 50)
# 1           1            Func_act                relu
# 2           2                 reg  1.3333333333333333

# %% [markdown]
# Con base en el gráfico anterior, se concluye a partir de el resultado de 'accuracy' (precisión) que es la probabilidad de acierto en la predicción obtenido utilizando las variables del grupo MF es de 0.89778 mientras que para el grupo de variables del grupo MFI es de 0.89278. Ambas especificaciones tienen un alto desempeño, sin embargo el modelo óptimo que se utilizará para realizar las predicciones es el modelo 11 con los siguientes hiper parámetros:
#
# - Hidden Layers (número de capas, número de neuronas)= (20,20,20)
# - Función de activación = Relu
# - Regularización = 0
#
# Este modelo tiene una probabilidad de error de 0.10222 que es 1-Accuracy.
#
# Para calcular la confiabilidad del modelo utilizamos la cota de Chernoff:
#
# ![image.png](attachment:image.png)
# Tomado de las notas del curso Machine Learning del profesor Fernando Lozano.
#
# Se tienen 9000 observaciones que son partidas 80% para entrenamiento y 20% para pruebas. Esto deja para entrenamiento 7200 observaciones que la validación cruzada subdivide en  5 subconjuntos iguales de 1440 observaciones cada uno, y en cada una de las 5 iteraciones entrena con 5760 observaciones y prueba con 1440 que corresonde a $S_{test}$.
#
# Si fijamos una precision $\epsilon = 0.05$ y despejando $\delta$ de la desigualdad nos da que $\delta \geq 0.0015$, por lo anterior la confiabilidad $\leq 0.9985$.
#
# Investigando un poco más encontramos en https://machinelearningmastery.com/confidence-intervals-for-machine-learning/ como calcular la confiabilidad de la precisión (métrica Accuracy) del modelo, asumiendo una distribución normal de esta métrica que es una proporción.  Tenemos una accuracy de 0.89778 con nuestro mejor modelo. $P(error) = 1 - Accuracy = 0.1022$
#
# El intervalo de confianza de la probabilidad de error del modelo se cálcula de la siguiente manera:
#
# $error \pm z*\sqrt{(error*(1-error)/n}$
#
# ASi las cosas con $Z= 1.96$ para un intervalo del 95% de confiabilidad para el error, el radio del intervalo nos queda de la siguiente manera:

# %%
n = 1440
error = 1-df_metricas.iloc[0,2]
Radio = 1.96*np.sqrt((error*(1-error)/n))
print('Radio del intervalo =', Radio)
# Out:
# Radio del intervalo = 0.01564687909639917

# %% [markdown]
# Por lo tanto, el intervalo de confianza para el error del mejor modelo es: $0.1022 \pm 0.0156$ con una confiabilidad el 95%.
# que es un intervalo de confianza binomial para proporciones.

# %% [markdown]
# A continuación se crea el vector de predicciones y_test con el modelo 43 que es el modelo óptimo con las variables del grupo MF que fue entrenado y validado anteriormente utilizando técnicas de validación cruzada (k-fold=5), utilizando las etiquetas de la base de x_test proveidas.

# %%
# crear DataFrame de resultados 

data  = { "Accuracy": [acc1, acc2],
         "Precision":[prec1, prec2],
         "Recall" : [rec1, rec2],
         "Balanced Accuracy" : [bal1, bal2],
         "F1": [f1_1, f1_2]        
        }

df_res = pd.DataFrame (data, index = [str(cont_m1),str(cont_m2)])

df_res
# Out:
#      Accuracy  Precision   Recall  Balanced Accuracy       F1
# 11    0.89778    0.89379  0.88744            0.89717  0.89061
# 103   0.89278    0.87200  0.90403            0.89344  0.88773

# %%
# cargar base de x-test dada por el profesor Fernando Lozano
df2 = pd.read_csv("xtest.txt", header=None, sep='\s+')

# Se estandarizan las variables 
df2 = estandarizacion(X_test)

#Se renombran las variables de X_test
df2.rename(columns={0:'Var_0',1:'Var_1', 2:'Var_2',3:'Var_3',4:'Var_4',5:'Var_5',6:'Var_6',7:'Var_7',8:'Var_8',
                   9:'Var_9',10:'Var_10',11:'Var_11',12:'Var_12',13:'Var_13',14:'Var_14',15:'Var_15'},inplace=True)

df2
# Out:
#          Var_0     Var_1     Var_2     Var_3     Var_4     Var_5     Var_6  \
# 0    -0.937456 -1.294068 -1.440907 -0.764606 -1.523297 -2.024207 -0.938510
# 1    -0.926491 -1.167529 -1.527917 -0.575190 -1.899265 -3.399557 -0.923945
# 2    -0.850250 -1.165065 -1.414666 -0.455436 -1.822787 -3.052432 -0.851090
# 3    -0.847436 -1.172686 -1.386361 -0.493226 -1.732717 -2.696403 -0.849114
# 4    -0.846660 -1.138157 -1.356066 -0.537989 -1.629600 -2.342479 -0.847425
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -0.932281 -1.181764 -1.176749 -1.112136 -0.504189 -0.208677 -0.929682
# 1996 -0.931375 -1.180422 -1.038029 -1.282130  0.095809  0.357704 -0.931116
# 1997 -0.930922 -1.239655 -1.278914 -0.975943 -0.924860 -0.772334 -0.930415
# 1998 -0.926103 -1.173449 -1.165330 -1.100497 -0.499272 -0.203066 -0.923945
# 1999 -0.925876 -1.240198 -1.231927 -1.017899 -0.767076 -0.539548 -0.927355
#
#          Var_7     Var_8     Var_9    Var_10    Var_11    Var_12    Var_13  \
# 0    -1.203007  0.307583  0.410344  1.503576  1.754183  0.881099  2.408114
# 1    -1.184411  0.688500 -0.419119  0.350040  2.360809  0.566595  3.071943
# 2    -1.058039  0.734280  0.298400  1.505944  2.231907  0.380615  2.705791
# 3    -1.053468  0.311154  0.473297  1.631492  2.085971  0.434953  2.535894
# 4    -1.052208  0.597758  0.280355  1.276944  1.918151  0.506393  2.351283
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -1.194217  0.863823 -0.431703  0.401327  0.415305  1.569756  1.063824
# 1996 -1.192681 -0.779877  0.103729  0.402110 -0.197047  1.943178  0.542061
# 1997 -1.191913  1.038465  0.046595  1.019251  0.923324  1.279055  1.533437
# 1998 -1.183755  0.462553 -0.330961  0.414861  0.402998  1.552905  1.040654
# 1999 -1.183372 -0.214928  0.498091  1.107328  0.723295  1.369561  1.332175
#
#         Var_14    Var_15
# 0     1.824445  0.912586
# 1     2.529224  0.846071
# 2     2.376907  0.893512
# 3     2.206129  0.995463
# 4     2.011928  0.905644
# ...        ...       ...
# 1995  0.377147  0.412652
# 1996 -0.235154  0.697667
# 1997  0.908769  0.757788
# 1998  0.364535  0.163012
# 1999  0.696888  0.542477
#
# [2000 rows x 16 columns]

# %%
# Se trasnforman y crean las nuevas variables
df2['Var_13T'] = 1/df2['Var_13']
df2['Var_10T'] = df2['Var_10']*df2['Var_10']
df2['Var_1310'] = df2['Var_13T']-df2['Var_10T']


#Creamos las variables nuevas y se cateogorizan las variables que utilizaremos.
gp_list = ['Var_9', 'Var_14', 'Var_15']
for var in gp_list:
    df2 = get_category(df2, var, 3, ["Bajo", "Medio", "Alto"], 'gp', qcut = True)
   
    
gp0_list = ['Var_0','Var_1','Var_2','Var_6','Var_7']
for var in gp0_list:
    df2 = get_category(df2, var, 2, ["Bajo", "Alto"], 'gp0', qcut = True)
    

X_tes_est = get_category(df2, 'Var_8', 2, ["Bajo", "Alto"], 'gp3', qcut = True)
    
df2 = get_category(df2, 'Var_1310', 4, ["Muy bajo", "Bajo", "Medio", "Alto"], 'gpI2', qcut = True)

gpT_list = ['Var_10T','Var_13T']
for var in gpT_list:
    df2 = get_category(df2, var, 3, ["Bajo", "Medio", "Alto"], 'gpT', qcut = True)

df2
# Out:
#          Var_0     Var_1     Var_2     Var_3     Var_4     Var_5     Var_6  \
# 0    -0.937456 -1.294068 -1.440907 -0.764606 -1.523297 -2.024207 -0.938510
# 1    -0.926491 -1.167529 -1.527917 -0.575190 -1.899265 -3.399557 -0.923945
# 2    -0.850250 -1.165065 -1.414666 -0.455436 -1.822787 -3.052432 -0.851090
# 3    -0.847436 -1.172686 -1.386361 -0.493226 -1.732717 -2.696403 -0.849114
# 4    -0.846660 -1.138157 -1.356066 -0.537989 -1.629600 -2.342479 -0.847425
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -0.932281 -1.181764 -1.176749 -1.112136 -0.504189 -0.208677 -0.929682
# 1996 -0.931375 -1.180422 -1.038029 -1.282130  0.095809  0.357704 -0.931116
# 1997 -0.930922 -1.239655 -1.278914 -0.975943 -0.924860 -0.772334 -0.930415
# 1998 -0.926103 -1.173449 -1.165330 -1.100497 -0.499272 -0.203066 -0.923945
# 1999 -0.925876 -1.240198 -1.231927 -1.017899 -0.767076 -0.539548 -0.927355
#
#          Var_7     Var_8     Var_9  ...  gp_Var_14  gp_Var_15  gp0_Var_0  \
# 0    -1.203007  0.307583  0.410344  ...       Alto       Alto       Bajo
# 1    -1.184411  0.688500 -0.419119  ...       Alto       Alto       Bajo
# 2    -1.058039  0.734280  0.298400  ...       Alto       Alto       Bajo
# 3    -1.053468  0.311154  0.473297  ...       Alto       Alto       Bajo
# 4    -1.052208  0.597758  0.280355  ...       Alto       Alto       Bajo
# ...        ...       ...       ...  ...        ...        ...        ...
# 1995 -1.194217  0.863823 -0.431703  ...       Alto      Medio       Bajo
# 1996 -1.192681 -0.779877  0.103729  ...      Medio       Alto       Bajo
# 1997 -1.191913  1.038465  0.046595  ...       Alto       Alto       Bajo
# 1998 -1.183755  0.462553 -0.330961  ...       Alto      Medio       Bajo
# 1999 -1.183372 -0.214928  0.498091  ...       Alto      Medio       Bajo
#
#       gp0_Var_1  gp0_Var_2  gp0_Var_6  gp0_Var_7  gpI2_Var_1310  gpT_Var_10T  \
# 0          Bajo       Bajo       Bajo       Bajo           Bajo         Alto
# 1          Bajo       Bajo       Bajo       Bajo           Alto         Bajo
# 2          Bajo       Bajo       Bajo       Bajo           Bajo         Alto
# 3          Bajo       Bajo       Bajo       Bajo           Bajo         Alto
# 4          Bajo       Bajo       Bajo       Bajo          Medio         Alto
# ...         ...        ...        ...        ...            ...          ...
# 1995       Bajo       Bajo       Bajo       Bajo           Alto         Bajo
# 1996       Bajo       Bajo       Bajo       Bajo           Alto         Bajo
# 1997       Bajo       Bajo       Bajo       Bajo          Medio        Medio
# 1998       Bajo       Bajo       Bajo       Bajo           Alto         Bajo
# 1999       Bajo       Bajo       Bajo       Bajo          Medio         Alto
#
#      gpT_Var_13T
# 0          Medio
# 1          Medio
# 2          Medio
# 3          Medio
# 4          Medio
# ...          ...
# 1995        Alto
# 1996        Alto
# 1997        Alto
# 1998        Alto
# 1999        Alto
#
# [2000 rows x 30 columns]

# %% [markdown]
# ## AQUI VOY AHORA SIGUE CREAR DUMMIES Y ESCOGER LAS MISMAS CON LAS QUE SE ENTRENO.  CREO QUE TOCA CON ONE HOT Y NO QUITAR NINGUNA.  LUEGO CREAR EL DATA FRAME CON LA MISMA LISTA QUE EN EL ENTRANAMIENTO.

# %%
# crear vector de predicciones del mejor modelo de todas las especificaciones con x-test para generar y_test

# cargar base de x-test dada por el profesor Fernando Lozano
x_test = Xdata = pd.read_csv("xtest.txt", header=None, sep='\s+')

# crear y_hat vector de predicciones/etiquetas para la base de x-test dada
y_test = ModeloMF_opt.predict(x_test)



# convertir DataFrame de predicciones en .txt
np.savetxt("ytest.txt", y_test, delimiter=" ")

# %%
# Out:
# [1. 1. 1. ... 1. 1. 1.]
